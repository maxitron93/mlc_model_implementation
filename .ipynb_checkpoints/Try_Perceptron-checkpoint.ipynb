# %%
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.2)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %% [markdown]
# # Create document embeddings by averaging word embeddings

# %%
# Import the libraries
import os
import numpy as np
from numpy import load
from scipy.sparse import load_npz
import tensorflow as tf
from tensorflow.keras.mixed_precision import experimental as mixed_precision
from tensorflow.keras.layers import Input, Conv1D, GlobalMaxPooling1D, concatenate, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Precision, Recall
from tensorflow_addons.metrics import F1Score
import matplotlib.pyplot as plt

# %%
# Check that a GPU is available
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Not sure why, but I need this to get TF to work
# from: https://www.tensorflow.org/guide/gpu#limiting_gpu_memory_growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ### Load in the data

# %%
# Define the load path
load_path = '../Datasets/AmazonCat-13K/processed/'

# %%
# Load the X_train
X_train_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_train_averaged.npz', allow_pickle=True)
X_train = list(X_train_data['arr_0'])

# %%
# Load the X_test
X_test_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_test_averaged.npz', allow_pickle=True)
X_test = list(X_test_data['arr_0'])

# %%
# Load y_train
y_train_sparse = load_npz(load_path + 'y_train_sparse_averaged.npz').astype('int64')

# %%
# Load y_test
y_test_sparse = load_npz(load_path + 'y_test_sparse_averaged.npz').astype('int64')

# %%
# Check the shape of the X data
print(f'X_train: ({len(X_train)}, {len(X_train[0])})')
print(f'X_test: ({len(X_test)}, {len(X_test[0])})')
# Out:
# X_train: (1120773, 201)
# X_test: (373591, 201)

# %%
# Check the shape of the y data
print(f'y_train: {y_train_sparse.shape}')
print(f'y_test: {y_test_sparse.shape}')
# Out:
# y_train: (1120773, 14295)
# y_test: (373591, 14295)

# %% [markdown]
# ### Create Sparse Tensors

# %%
# Create function to convert sparse matrix to SparseTensor
def convert_sparse_matrix_to_sparse_tensor(sparse_matrix):
    coo = sparse_matrix.tocoo()
    indices = np.mat([coo.row, coo.col]).transpose()
    return tf.SparseTensor(indices, coo.data, coo.shape)

# %%
# Create sparse tensor of y_train
y_train_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_train_sparse))

# %%
# Create sparse tensor of y_test
y_test_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_test_sparse))

# %% [markdown]
# ### Create the TensorFlow Dataset

# %%
# Create function to convert SparseTensor to dense tensor
def convert_sparse_tensor_to_dense_tensor(X, y_sparse):
    y_dense = tf.sparse.to_dense(y_sparse)
    return X, y_dense

# %%
# Create the train dataset
tr_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train_sparse_tensor))
tr_dataset = tr_dataset.map(convert_sparse_tensor_to_dense_tensor)
tr_dataset = tr_dataset.batch(batch_size=1024)

# %%
# Create the test dataset
val_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test_sparse_tensor))
val_dataset = val_dataset.map(convert_sparse_tensor_to_dense_tensor)
val_dataset = val_dataset.batch(batch_size=1024)

# %% [markdown]
# ### Define the model layers

# %%
# Define the perceptron architecture
i = Input(shape=len(X_train[0]), dtype=tf.int32)
x = Dense(units=len(X_train[0]), activation='relu', use_bias=False)(i)
x = Dense(y_train_sparse.shape[1], activation='sigmoid', use_bias=False)(x)

# %%
# Build the model
model = Model(i, x)

# %%
# Have a look at the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 201)]             0
# _________________________________________________________________
# dense (Dense)                (None, 201)               40401
# _________________________________________________________________
# dense_1 (Dense)              (None, 14295)             2873295
# =================================================================
# Total params: 2,913,696
# Trainable params: 2,913,696
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define how the model should be trained

# %%
# Define how the model should be trained
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.025), # CNN-Kim uses SGD with Adelta update rule
              loss='binary_crossentropy',
              metrics=[Recall(name='Recall'),
                       Precision(name='Precision'),
                       Precision(top_k=1, name='PrecisionAt1'),
                       Precision(top_k=3, name='PrecisionAt3'),
                       Precision(top_k=5, name='PrecisionAt5'),
                       Precision(top_k=10, name='PrecisionAt10'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='micro', 
                               threshold=0.5,
                               name='MicroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='macro', 
                               threshold=0.5,
                               name='MacroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='weighted', 
                               threshold=0.5,
                               name='WeightedF1')
                      ])

# %%
# Create learning rate decay function
def lr_scheduler(epoch, lr):
    learning_rate = lr * 0.9
    print(f'Learning Rate: {learning_rate}')
    return learning_rate

# define the learning rate scheduler
callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %% [markdown]
# ### Train the model

# %%
# Train the model
result = model.fit(tr_dataset,
                   epochs=10,
                   validation_data=val_dataset,
                   callbacks=[callback]);
# Out:
# Train for 1095 steps, validate for 365 steps
# Learning Rate: 0.02250000033527613
# Epoch 1/10
# 1095/1095 [==============================] - 125s 114ms/step - loss: 0.0034 - Recall: 0.2078 - Precision: 0.1311 - PrecisionAt1: 0.7184 - PrecisionAt3: 0.5030 - PrecisionAt5: 0.3851 - PrecisionAt10: 0.2468 - MicroF1: 0.1607 - MacroF1: 0.0084 - WeightedF1: 0.2508 - val_loss: 0.0012 - val_Recall: 0.2448 - val_Precision: 0.7545 - val_PrecisionAt1: 0.7631 - val_PrecisionAt3: 0.5541 - val_PrecisionAt5: 0.4291 - val_PrecisionAt10: 0.2746 - val_MicroF1: 0.3697 - val_MacroF1: 0.0211 - val_WeightedF1: 0.2998
# Learning Rate: 0.020250000804662705
# Epoch 2/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0012 - Recall: 0.2725 - Precision: 0.7477 - PrecisionAt1: 0.7719 - PrecisionAt3: 0.5681 - PrecisionAt5: 0.4414 - PrecisionAt10: 0.2823 - MicroF1: 0.3994 - MacroF1: 0.0329 - WeightedF1: 0.3291 - val_loss: 0.0012 - val_Recall: 0.2760 - val_Precision: 0.7530 - val_PrecisionAt1: 0.7760 - val_PrecisionAt3: 0.5729 - val_PrecisionAt5: 0.4462 - val_PrecisionAt10: 0.2850 - val_MicroF1: 0.4040 - val_MacroF1: 0.0398 - val_WeightedF1: 0.3329
# Learning Rate: 0.01822500005364418
# Epoch 3/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0011 - Recall: 0.2894 - Precision: 0.7494 - PrecisionAt1: 0.7801 - PrecisionAt3: 0.5794 - PrecisionAt5: 0.4523 - PrecisionAt10: 0.2891 - MicroF1: 0.4175 - MacroF1: 0.0524 - WeightedF1: 0.3483 - val_loss: 0.0011 - val_Recall: 0.2877 - val_Precision: 0.7479 - val_PrecisionAt1: 0.7800 - val_PrecisionAt3: 0.5785 - val_PrecisionAt5: 0.4516 - val_PrecisionAt10: 0.2882 - val_MicroF1: 0.4155 - val_MacroF1: 0.0559 - val_WeightedF1: 0.3453
# Learning Rate: 0.01640249937772751
# Epoch 4/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0011 - Recall: 0.2972 - Precision: 0.7490 - PrecisionAt1: 0.7836 - PrecisionAt3: 0.5842 - PrecisionAt5: 0.4572 - PrecisionAt10: 0.2923 - MicroF1: 0.4256 - MacroF1: 0.0698 - WeightedF1: 0.3572 - val_loss: 0.0011 - val_Recall: 0.2918 - val_Precision: 0.7471 - val_PrecisionAt1: 0.7807 - val_PrecisionAt3: 0.5808 - val_PrecisionAt5: 0.4541 - val_PrecisionAt10: 0.2899 - val_MicroF1: 0.4197 - val_MacroF1: 0.0673 - val_WeightedF1: 0.3509
# Learning Rate: 0.014762249775230885
# Epoch 5/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0011 - Recall: 0.3017 - Precision: 0.7491 - PrecisionAt1: 0.7854 - PrecisionAt3: 0.5870 - PrecisionAt5: 0.4602 - PrecisionAt10: 0.2943 - MicroF1: 0.4302 - MacroF1: 0.0855 - WeightedF1: 0.3624 - val_loss: 0.0011 - val_Recall: 0.2920 - val_Precision: 0.7498 - val_PrecisionAt1: 0.7811 - val_PrecisionAt3: 0.5822 - val_PrecisionAt5: 0.4554 - val_PrecisionAt10: 0.2907 - val_MicroF1: 0.4203 - val_MacroF1: 0.0757 - val_WeightedF1: 0.3520
# Learning Rate: 0.013286024797707796
# Epoch 6/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0011 - Recall: 0.3047 - Precision: 0.7503 - PrecisionAt1: 0.7871 - PrecisionAt3: 0.5894 - PrecisionAt5: 0.4626 - PrecisionAt10: 0.2959 - MicroF1: 0.4334 - MacroF1: 0.1007 - WeightedF1: 0.3660 - val_loss: 0.0011 - val_Recall: 0.2949 - val_Precision: 0.7486 - val_PrecisionAt1: 0.7808 - val_PrecisionAt3: 0.5833 - val_PrecisionAt5: 0.4564 - val_PrecisionAt10: 0.2914 - val_MicroF1: 0.4231 - val_MacroF1: 0.0842 - val_WeightedF1: 0.3549
# Learning Rate: 0.011957421898841858
# Epoch 7/10
# 1095/1095 [==============================] - 124s 113ms/step - loss: 0.0011 - Recall: 0.3072 - Precision: 0.7521 - PrecisionAt1: 0.7889 - PrecisionAt3: 0.5917 - PrecisionAt5: 0.4649 - PrecisionAt10: 0.2973 - MicroF1: 0.4362 - MacroF1: 0.1163 - WeightedF1: 0.3690 - val_loss: 0.0011 - val_Recall: 0.2990 - val_Precision: 0.7463 - val_PrecisionAt1: 0.7826 - val_PrecisionAt3: 0.5846 - val_PrecisionAt5: 0.4576 - val_PrecisionAt10: 0.2920 - val_MicroF1: 0.4269 - val_MacroF1: 0.0907 - val_WeightedF1: 0.3582
# Learning Rate: 0.010761679708957672
# Epoch 8/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0011 - Recall: 0.3094 - Precision: 0.7546 - PrecisionAt1: 0.7910 - PrecisionAt3: 0.5942 - PrecisionAt5: 0.4672 - PrecisionAt10: 0.2987 - MicroF1: 0.4389 - MacroF1: 0.1315 - WeightedF1: 0.3718 - val_loss: 0.0011 - val_Recall: 0.3027 - val_Precision: 0.7444 - val_PrecisionAt1: 0.7846 - val_PrecisionAt3: 0.5858 - val_PrecisionAt5: 0.4588 - val_PrecisionAt10: 0.2928 - val_MicroF1: 0.4304 - val_MacroF1: 0.0966 - val_WeightedF1: 0.3613
# Learning Rate: 0.009685512073338032
# Epoch 9/10
# 1095/1095 [==============================] - 125s 114ms/step - loss: 0.0011 - Recall: 0.3116 - Precision: 0.7574 - PrecisionAt1: 0.7931 - PrecisionAt3: 0.5967 - PrecisionAt5: 0.4695 - PrecisionAt10: 0.3001 - MicroF1: 0.4415 - MacroF1: 0.1465 - WeightedF1: 0.3744 - val_loss: 0.0011 - val_Recall: 0.3051 - val_Precision: 0.7441 - val_PrecisionAt1: 0.7859 - val_PrecisionAt3: 0.5874 - val_PrecisionAt5: 0.4602 - val_PrecisionAt10: 0.2936 - val_MicroF1: 0.4328 - val_MacroF1: 0.1007 - val_WeightedF1: 0.3639
# Learning Rate: 0.008716960530728101
# Epoch 10/10
# 1095/1095 [==============================] - 129s 117ms/step - loss: 0.0011 - Recall: 0.3136 - Precision: 0.7601 - PrecisionAt1: 0.7950 - PrecisionAt3: 0.5992 - PrecisionAt5: 0.4717 - PrecisionAt10: 0.3014 - MicroF1: 0.4441 - MacroF1: 0.1613 - WeightedF1: 0.3769 - val_loss: 0.0011 - val_Recall: 0.3081 - val_Precision: 0.7426 - val_PrecisionAt1: 0.7870 - val_PrecisionAt3: 0.5889 - val_PrecisionAt5: 0.4617 - val_PrecisionAt10: 0.2945 - val_MicroF1: 0.4355 - val_MacroF1: 0.1050 - val_WeightedF1: 0.3670

# %%
# Plot the Recall metric at each itteration
plt.plot(result.history['Recall'], label='train_Recall');
plt.plot(result.history['val_Recall'], label='val_Recall');
plt.legend();

# %%
# Plot the Precision metric at each itteration
plt.plot(result.history['Precision'], label='train_Precision');
plt.plot(result.history['val_Precision'], label='val_Precision');
plt.legend();

# %%
# Plot the PrecisionAt1 metric at each itteration
plt.plot(result.history['PrecisionAt1'], label='train_PrecisionAt1');
plt.plot(result.history['val_PrecisionAt1'], label='val_PrecisionAt1');
plt.legend();

# %%
# Plot the PrecisionAt3 metric at each itteration
plt.plot(result.history['PrecisionAt3'], label='train_PrecisionAt3l');
plt.plot(result.history['val_PrecisionAt3'], label='val_PrecisionAt3');
plt.legend();

# %%
# Plot the PrecisionAt5 metric at each itteration
plt.plot(result.history['PrecisionAt5'], label='train_PrecisionAt5');
plt.plot(result.history['val_PrecisionAt5'], label='val_PrecisionAt5');
plt.legend();

# %%
# Plot the PrecisionAt10 metric at each itteration
plt.plot(result.history['PrecisionAt10'], label='train_PrecisionAt10');
plt.plot(result.history['val_PrecisionAt10'], label='val_PrecisionAt10');
plt.legend();

# %%
# Plot the MicroF1 metric at each itteration
plt.plot(result.history['MicroF1'], label='train_MicroF1');
plt.plot(result.history['val_MicroF1'], label='val_MicroF1');
plt.legend();

# %%
# Plot the MacroF1 metric at each itteration
plt.plot(result.history['MacroF1'], label='train_MacroF1');
plt.plot(result.history['val_MacroF1'], label='val_MacroF1');
plt.legend();

# %%
# Plot the WeightedF1 metric at each itteration
plt.plot(result.history['WeightedF1'], label='train_WeightedF1');
plt.plot(result.history['val_WeightedF1'], label='val_WeightedF1');
plt.legend();
