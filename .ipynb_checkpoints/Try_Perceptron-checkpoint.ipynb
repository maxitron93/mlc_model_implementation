# %%
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.2)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %% [markdown]
# # Create document embeddings by averaging word embeddings

# %%
# Import the libraries
import os
import numpy as np
from numpy import load
from scipy.sparse import load_npz
import tensorflow as tf
from tensorflow.keras.mixed_precision import experimental as mixed_precision
from tensorflow.keras.layers import Input, Conv1D, GlobalMaxPooling1D, concatenate, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Precision, Recall
from tensorflow_addons.metrics import F1Score
import matplotlib.pyplot as plt

# %%
# Check that a GPU is available
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Not sure why, but I need this to get TF to work
# from: https://www.tensorflow.org/guide/gpu#limiting_gpu_memory_growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ### Load in the data

# %%
# Define the load path
load_path = '../Datasets/AmazonCat-13K/processed/'

# %%
# Load the X_train
X_train_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_train_averaged.npz', allow_pickle=True)
X_train = list(X_train_data['arr_0'])

# %%
# Load the X_test
X_test_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_test_averaged.npz', allow_pickle=True)
X_test = list(X_test_data['arr_0'])

# %%
# Load y_train
y_train_sparse = load_npz(load_path + 'y_train_sparse_averaged.npz').astype('int64')

# %%
# Load y_test
y_test_sparse = load_npz(load_path + 'y_test_sparse_averaged.npz').astype('int64')

# %%
# Check the shape of the X data
print(f'X_train: ({len(X_train)}, {len(X_train[0])})')
print(f'X_test: ({len(X_test)}, {len(X_test[0])})')
# Out:
# X_train: (1120773, 151)
# X_test: (373591, 151)

# %%
# Check the shape of the y data
print(f'y_train: {y_train_sparse.shape}')
print(f'y_test: {y_test_sparse.shape}')
# Out:
# y_train: (1120773, 14295)
# y_test: (373591, 14295)

# %% [markdown]
# ### Create Sparse Tensors

# %%
# Create function to convert sparse matrix to SparseTensor
def convert_sparse_matrix_to_sparse_tensor(sparse_matrix):
    coo = sparse_matrix.tocoo()
    indices = np.mat([coo.row, coo.col]).transpose()
    return tf.SparseTensor(indices, coo.data, coo.shape)

# %%
# Create sparse tensor of y_train
y_train_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_train_sparse))

# %%
# Create sparse tensor of y_test
y_test_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_test_sparse))

# %% [markdown]
# ### Create the TensorFlow Dataset

# %%
# Create function to convert SparseTensor to dense tensor
def convert_sparse_tensor_to_dense_tensor(X, y_sparse):
    y_dense = tf.sparse.to_dense(y_sparse)
    return X, y_dense

# %%
# Create the train dataset
tr_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train_sparse_tensor))
tr_dataset = tr_dataset.map(convert_sparse_tensor_to_dense_tensor)
tr_dataset = tr_dataset.batch(batch_size=1024)

# %%
# Create the test dataset
val_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test_sparse_tensor))
val_dataset = val_dataset.map(convert_sparse_tensor_to_dense_tensor)
val_dataset = val_dataset.batch(batch_size=1024)

# %% [markdown]
# ### Define the model layers

# %%
# Define the perceptron architecture
i = Input(shape=len(X_train[0]), dtype=tf.int32)
x = Dense(y_train_sparse.shape[1], activation='sigmoid')(i)

# %%
# Build the model
model = Model(i, x)

# %%
# Have a look at the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 151)]             0
# _________________________________________________________________
# dense (Dense)                (None, 14295)             2172840
# =================================================================
# Total params: 2,172,840
# Trainable params: 2,172,840
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define how the model should be trained

# %%
# Define how the model should be trained
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.025), # CNN-Kim uses SGD with Adelta update rule
              loss='binary_crossentropy',
              metrics=[Recall(name='Recall'),
                       Precision(name='Precision'),
                       Precision(top_k=1, name='PrecisionAt1'),
                       Precision(top_k=3, name='PrecisionAt3'),
                       Precision(top_k=5, name='PrecisionAt5'),
                       Precision(top_k=10, name='PrecisionAt10'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='micro', 
                               threshold=0.5,
                               name='MicroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='macro', 
                               threshold=0.5,
                               name='MacroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='weighted', 
                               threshold=0.5,
                               name='WeightedF1')
                      ])

# %%
# Create learning rate decay function
def lr_scheduler(epoch, lr):
    learning_rate = lr * 0.9
    print(f'Learning Rate: {learning_rate}')
    return learning_rate

# define the learning rate scheduler
callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %% [markdown]
# ### Train the model

# %%
# Train the model
result = model.fit(tr_dataset,
                   epochs=10,
                   validation_data=val_dataset,
                   callbacks=[callback]);
# Out:
# Train for 1095 steps, validate for 365 steps
# Learning Rate: 0.02250000033527613
# Epoch 1/10
# 1095/1095 [==============================] - 125s 114ms/step - loss: 0.0146 - Recall: 0.1708 - Precision: 0.0505 - PrecisionAt1: 0.7110 - PrecisionAt3: 0.4826 - PrecisionAt5: 0.3645 - PrecisionAt10: 0.2321 - MicroF1: 0.0780 - MacroF1: 0.0038 - WeightedF1: 0.2038 - val_loss: 0.0026 - val_Recall: 0.1953 - val_Precision: 0.4313 - val_PrecisionAt1: 0.7280 - val_PrecisionAt3: 0.5093 - val_PrecisionAt5: 0.3887 - val_PrecisionAt10: 0.2484 - val_MicroF1: 0.2689 - val_MacroF1: 0.0083 - val_WeightedF1: 0.2386
# Learning Rate: 0.020250000804662705
# Epoch 2/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0021 - Recall: 0.2006 - Precision: 0.4907 - PrecisionAt1: 0.7301 - PrecisionAt3: 0.5135 - PrecisionAt5: 0.3943 - PrecisionAt10: 0.2524 - MicroF1: 0.2848 - MacroF1: 0.0118 - WeightedF1: 0.2460 - val_loss: 0.0018 - val_Recall: 0.2053 - val_Precision: 0.5419 - val_PrecisionAt1: 0.7305 - val_PrecisionAt3: 0.5172 - val_PrecisionAt5: 0.3981 - val_PrecisionAt10: 0.2552 - val_MicroF1: 0.2978 - val_MacroF1: 0.0147 - val_WeightedF1: 0.2519
# Learning Rate: 0.01822500005364418
# Epoch 3/10
# 1095/1095 [==============================] - 122s 111ms/step - loss: 0.0017 - Recall: 0.2073 - Precision: 0.5926 - PrecisionAt1: 0.7322 - PrecisionAt3: 0.5192 - PrecisionAt5: 0.4009 - PrecisionAt10: 0.2571 - MicroF1: 0.3072 - MacroF1: 0.0179 - WeightedF1: 0.2551 - val_loss: 0.0016 - val_Recall: 0.2099 - val_Precision: 0.5767 - val_PrecisionAt1: 0.7321 - val_PrecisionAt3: 0.5209 - val_PrecisionAt5: 0.4023 - val_PrecisionAt10: 0.2581 - val_MicroF1: 0.3077 - val_MacroF1: 0.0195 - val_WeightedF1: 0.2578
# Learning Rate: 0.01640249937772751
# Epoch 4/10
# 1095/1095 [==============================] - 122s 111ms/step - loss: 0.0015 - Recall: 0.2109 - Precision: 0.6466 - PrecisionAt1: 0.7338 - PrecisionAt3: 0.5223 - PrecisionAt5: 0.4045 - PrecisionAt10: 0.2597 - MicroF1: 0.3181 - MacroF1: 0.0231 - WeightedF1: 0.2599 - val_loss: 0.0015 - val_Recall: 0.2128 - val_Precision: 0.6045 - val_PrecisionAt1: 0.7330 - val_PrecisionAt3: 0.5229 - val_PrecisionAt5: 0.4049 - val_PrecisionAt10: 0.2599 - val_MicroF1: 0.3148 - val_MacroF1: 0.0237 - val_WeightedF1: 0.2615
# Learning Rate: 0.014762249775230885
# Epoch 5/10
# 1095/1095 [==============================] - 122s 111ms/step - loss: 0.0014 - Recall: 0.2132 - Precision: 0.6761 - PrecisionAt1: 0.7351 - PrecisionAt3: 0.5244 - PrecisionAt5: 0.4070 - PrecisionAt10: 0.2614 - MicroF1: 0.3242 - MacroF1: 0.0279 - WeightedF1: 0.2631 - val_loss: 0.0014 - val_Recall: 0.2147 - val_Precision: 0.6188 - val_PrecisionAt1: 0.7337 - val_PrecisionAt3: 0.5245 - val_PrecisionAt5: 0.4066 - val_PrecisionAt10: 0.2611 - val_MicroF1: 0.3187 - val_MacroF1: 0.0272 - val_WeightedF1: 0.2638
# Learning Rate: 0.013286024797707796
# Epoch 6/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0014 - Recall: 0.2148 - Precision: 0.6884 - PrecisionAt1: 0.7361 - PrecisionAt3: 0.5260 - PrecisionAt5: 0.4088 - PrecisionAt10: 0.2627 - MicroF1: 0.3275 - MacroF1: 0.0321 - WeightedF1: 0.2654 - val_loss: 0.0014 - val_Recall: 0.2160 - val_Precision: 0.6328 - val_PrecisionAt1: 0.7344 - val_PrecisionAt3: 0.5256 - val_PrecisionAt5: 0.4078 - val_PrecisionAt10: 0.2620 - val_MicroF1: 0.3221 - val_MacroF1: 0.0301 - val_WeightedF1: 0.2655
# Learning Rate: 0.011957421898841858
# Epoch 7/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0014 - Recall: 0.2160 - Precision: 0.6928 - PrecisionAt1: 0.7369 - PrecisionAt3: 0.5272 - PrecisionAt5: 0.4102 - PrecisionAt10: 0.2636 - MicroF1: 0.3294 - MacroF1: 0.0358 - WeightedF1: 0.2670 - val_loss: 0.0014 - val_Recall: 0.2171 - val_Precision: 0.6406 - val_PrecisionAt1: 0.7348 - val_PrecisionAt3: 0.5265 - val_PrecisionAt5: 0.4088 - val_PrecisionAt10: 0.2626 - val_MicroF1: 0.3243 - val_MacroF1: 0.0327 - val_WeightedF1: 0.2668
# Learning Rate: 0.010761679708957672
# Epoch 8/10
# 1095/1095 [==============================] - 122s 112ms/step - loss: 0.0013 - Recall: 0.2170 - Precision: 0.6960 - PrecisionAt1: 0.7375 - PrecisionAt3: 0.5282 - PrecisionAt5: 0.4114 - PrecisionAt10: 0.2644 - MicroF1: 0.3308 - MacroF1: 0.0395 - WeightedF1: 0.2683 - val_loss: 0.0014 - val_Recall: 0.2179 - val_Precision: 0.6443 - val_PrecisionAt1: 0.7354 - val_PrecisionAt3: 0.5272 - val_PrecisionAt5: 0.4095 - val_PrecisionAt10: 0.2631 - val_MicroF1: 0.3257 - val_MacroF1: 0.0350 - val_WeightedF1: 0.2678
# Learning Rate: 0.009685512073338032
# Epoch 9/10
# 1095/1095 [==============================] - 123s 112ms/step - loss: 0.0013 - Recall: 0.2176 - Precision: 0.6996 - PrecisionAt1: 0.7381 - PrecisionAt3: 0.5291 - PrecisionAt5: 0.4123 - PrecisionAt10: 0.2650 - MicroF1: 0.3320 - MacroF1: 0.0426 - WeightedF1: 0.2692 - val_loss: 0.0014 - val_Recall: 0.2186 - val_Precision: 0.6469 - val_PrecisionAt1: 0.7359 - val_PrecisionAt3: 0.5277 - val_PrecisionAt5: 0.4100 - val_PrecisionAt10: 0.2635 - val_MicroF1: 0.3267 - val_MacroF1: 0.0369 - val_WeightedF1: 0.2686
# Learning Rate: 0.008716960530728101
# Epoch 10/10
# 1095/1095 [==============================] - 122s 112ms/step - loss: 0.0013 - Recall: 0.2182 - Precision: 0.7011 - PrecisionAt1: 0.7387 - PrecisionAt3: 0.5298 - PrecisionAt5: 0.4130 - PrecisionAt10: 0.2656 - MicroF1: 0.3328 - MacroF1: 0.0451 - WeightedF1: 0.2700 - val_loss: 0.0014 - val_Recall: 0.2191 - val_Precision: 0.6491 - val_PrecisionAt1: 0.7364 - val_PrecisionAt3: 0.5282 - val_PrecisionAt5: 0.4105 - val_PrecisionAt10: 0.2638 - val_MicroF1: 0.3277 - val_MacroF1: 0.0383 - val_WeightedF1: 0.2692

# %%
# Plot the Recall metric at each itteration
plt.plot(result.history['Recall'], label='train_Recall');
plt.plot(result.history['val_Recall'], label='val_Recall');
plt.legend();

# %%
# Plot the Precision metric at each itteration
plt.plot(result.history['Precision'], label='train_Precision');
plt.plot(result.history['val_Precision'], label='val_Precision');
plt.legend();

# %%
# Plot the PrecisionAt1 metric at each itteration
plt.plot(result.history['PrecisionAt1'], label='train_PrecisionAt1');
plt.plot(result.history['val_PrecisionAt1'], label='val_PrecisionAt1');
plt.legend();

# %%
# Plot the PrecisionAt3 metric at each itteration
plt.plot(result.history['PrecisionAt3'], label='train_PrecisionAt3l');
plt.plot(result.history['val_PrecisionAt3'], label='val_PrecisionAt3');
plt.legend();

# %%
# Plot the PrecisionAt5 metric at each itteration
plt.plot(result.history['PrecisionAt5'], label='train_PrecisionAt5');
plt.plot(result.history['val_PrecisionAt5'], label='val_PrecisionAt5');
plt.legend();

# %%
# Plot the PrecisionAt10 metric at each itteration
plt.plot(result.history['PrecisionAt10'], label='train_PrecisionAt10');
plt.plot(result.history['val_PrecisionAt10'], label='val_PrecisionAt10');
plt.legend();

# %%
# Plot the MicroF1 metric at each itteration
plt.plot(result.history['MicroF1'], label='train_MicroF1');
plt.plot(result.history['val_MicroF1'], label='val_MicroF1');
plt.legend();

# %%
# Plot the MacroF1 metric at each itteration
plt.plot(result.history['MacroF1'], label='train_MacroF1');
plt.plot(result.history['val_MacroF1'], label='val_MacroF1');
plt.legend();

# %%
# Plot the WeightedF1 metric at each itteration
plt.plot(result.history['WeightedF1'], label='train_WeightedF1');
plt.plot(result.history['val_WeightedF1'], label='val_WeightedF1');
plt.legend();
