# %%
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.2)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Import the libraries
import os
import numpy as np
from numpy import load
from scipy.sparse import load_npz
import tensorflow as tf
from tensorflow.keras.mixed_precision import experimental as mixed_precision
from tensorflow.keras.layers import Input, Conv1D, GlobalMaxPooling1D, concatenate, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
import matplotlib.pyplot as plt

# %%
# Check that a GPU is available
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Not sure why, but I need this to get TF to work
# from: https://www.tensorflow.org/guide/gpu#limiting_gpu_memory_growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ### Load in the data

# %%
# Define the load path
load_path = '../Datasets/AmazonCat-13K/processed/'

# %%
# Load the X_train
X_train_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_train.npz')
X_train = X_train_data['arr_0']

# %%
# Load the X_test
X_test_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_test.npz')
X_test = X_test_data['arr_0']

# %%
# Load y_train
y_train_sparse = load_npz(load_path + 'y_train_sparse.npz').astype('int64')

# %%
# Load y_test
y_test_sparse = load_npz(load_path + 'y_test_sparse.npz').astype('int64')

# %%
# Check the shape of the X data
print(f'X_train: {X_train.shape}')
print(f'X_test: {X_test.shape}')
# Out:
# X_train: (1120773, 512)
# X_test: (373591, 512)

# %%
# Check the shape of the X data
print(f'y_train: {y_train_sparse.shape}')
print(f'y_test: {y_test_sparse.shape}')
# Out:
# y_train: (1120773, 14295)
# y_test: (373591, 14295)

# %% [markdown]
# ### Create Sparse Tensors

# %%
# Create function to convert sparse matrix to SparseTensor
def convert_sparse_matrix_to_sparse_tensor(sparse_matrix):
    coo = sparse_matrix.tocoo()
    indices = np.mat([coo.row, coo.col]).transpose()
    return tf.SparseTensor(indices, coo.data, coo.shape)

# %%
# Create sparse tensor of y_train
y_train_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_train_sparse))

# %%
# Create sparse tensor of y_test
y_test_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_test_sparse))

# %% [markdown]
# ### Create the TensorFlow Dataset

# %%
# Create function to convert SparseTensor to dense tensor
def convert_sparse_tensor_to_dense_tensor(X, y_sparse):
    y_dense = tf.sparse.to_dense(y_sparse)
    return X, y_dense

# %%
tr_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train_sparse_tensor))
tr_dataset = tr_dataset.map(convert_sparse_tensor_to_dense_tensor)
tr_dataset = tr_dataset.batch(batch_size=1024)

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test_sparse_tensor))
val_dataset = val_dataset.map(convert_sparse_tensor_to_dense_tensor)
val_dataset = val_dataset.batch(batch_size=1024)

# %% [markdown]
# ### Define the model layers

# %%
# Define the Input and Embedding layers
i = Input(shape=(X_train.shape[1]), dtype=tf.int32)
x = Dense(512, activation=None)(i)
x = Dropout(rate=0.5)(x)
x = Dense(512, activation=None)(x)
x = Dropout(rate=0.5)(x)
x = Dense(512, activation=None)(x)
x = Dropout(rate=0.5)(x)
x = Dense(y_train_sparse.shape[1], activation='sigmoid')(x)

# %%
# Build the model
model = Model(i, x)

# %%
# Have a look at the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 512)]             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 14295)             7333335
# =================================================================
# Total params: 8,121,303
# Trainable params: 8,121,303
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define how the model should be trained

# %%
# Define how the model should be trained
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0005), # CNN-Kim uses SGD with Adelta update rule
              loss='binary_crossentropy',
              metrics=[Recall(name='Recall'),
                       Precision(top_k=1, name='PrecisionAt1'),
                       Precision(top_k=3, name='PrecisionAt3'),
                       Precision(top_k=5, name='PrecisionAt5'),
                       Precision(top_k=10, name='PrecisionAt10'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='micro', 
                               threshold=0.5,
                               name='MicroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='macro', 
                               threshold=0.5,
                               name='MacroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='weighted', 
                               threshold=0.5,
                               name='WeightedF1')])

# %%
# Create learning rate decay function
def lr_scheduler(epoch, lr):
    learning_rate = lr * 0.9
    print(f'Learning Rate: {learning_rate}')
    return learning_rate

# define the learning rate scheduler
callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %% [markdown]
# ### Train the model

# %%
# Train the model
result = model.fit(tr_dataset,
                   epochs=10,
                   validation_data=val_dataset,
                   callbacks=[callback]);
# Out:
# Train for 1095 steps, validate for 365 steps
# Learning Rate: 0.0004500000213738531
# Epoch 1/10
# 1095/1095 [==============================] - 129s 118ms/step - loss: 12.8314 - Recall: 0.0533 - PrecisionAt1: 0.0900 - PrecisionAt3: 0.0640 - PrecisionAt5: 0.0527 - PrecisionAt10: 0.0373 - MicroF1: 0.0105 - MacroF1: 4.9312e-04 - WeightedF1: 0.0477 - val_loss: 1.0478 - val_Recall: 0.0812 - val_PrecisionAt1: 0.2796 - val_PrecisionAt3: 0.1526 - val_PrecisionAt5: 0.1078 - val_PrecisionAt10: 0.0588 - val_MicroF1: 0.1149 - val_MacroF1: 5.3353e-05 - val_WeightedF1: 0.0323
# Learning Rate: 0.0004050000192364678
# Epoch 2/10
# 1095/1095 [==============================] - 125s 114ms/step - loss: 0.9183 - Recall: 0.0518 - PrecisionAt1: 0.0868 - PrecisionAt3: 0.0665 - PrecisionAt5: 0.0586 - PrecisionAt10: 0.0465 - MicroF1: 0.0408 - MacroF1: 4.3930e-04 - WeightedF1: 0.0480 - val_loss: 0.6599 - val_Recall: 0.0076 - val_PrecisionAt1: 0.1166 - val_PrecisionAt3: 0.1171 - val_PrecisionAt5: 0.0790 - val_PrecisionAt10: 0.0481 - val_MicroF1: 0.0144 - val_MacroF1: 1.4449e-05 - val_WeightedF1: 0.0046
# Learning Rate: 0.0003645000251708552
# Epoch 3/10
# 1095/1095 [==============================] - 124s 114ms/step - loss: 0.6467 - Recall: 0.0524 - PrecisionAt1: 0.0847 - PrecisionAt3: 0.0673 - PrecisionAt5: 0.0607 - PrecisionAt10: 0.0499 - MicroF1: 0.0414 - MacroF1: 4.4021e-04 - WeightedF1: 0.0486 - val_loss: 0.4843 - val_Recall: 0.0136 - val_PrecisionAt1: 0.1522 - val_PrecisionAt3: 0.1707 - val_PrecisionAt5: 0.1250 - val_PrecisionAt10: 0.0746 - val_MicroF1: 0.0253 - val_MacroF1: 2.9469e-05 - val_WeightedF1: 0.0167
# Learning Rate: 0.0003280500357504934
# Epoch 4/10
# 1095/1095 [==============================] - 125s 114ms/step - loss: 0.4876 - Recall: 0.0528 - PrecisionAt1: 0.0839 - PrecisionAt3: 0.0687 - PrecisionAt5: 0.0633 - PrecisionAt10: 0.0539 - MicroF1: 0.0421 - MacroF1: 4.5263e-04 - WeightedF1: 0.0492 - val_loss: 0.3582 - val_Recall: 0.0241 - val_PrecisionAt1: 0.3013 - val_PrecisionAt3: 0.1664 - val_PrecisionAt5: 0.1151 - val_PrecisionAt10: 0.0721 - val_MicroF1: 0.0459 - val_MacroF1: 3.6997e-05 - val_WeightedF1: 0.0282
# Learning Rate: 0.00029524502169806513
# Epoch 5/10
# 1095/1095 [==============================] - 124s 114ms/step - loss: 0.3679 - Recall: 0.0529 - PrecisionAt1: 0.0823 - PrecisionAt3: 0.0692 - PrecisionAt5: 0.0646 - PrecisionAt10: 0.0559 - MicroF1: 0.0424 - MacroF1: 4.4127e-04 - WeightedF1: 0.0495 - val_loss: 0.2971 - val_Recall: 5.8223e-04 - val_PrecisionAt1: 0.1677 - val_PrecisionAt3: 0.1300 - val_PrecisionAt5: 0.0939 - val_PrecisionAt10: 0.0696 - val_MicroF1: 0.0012 - val_MacroF1: 3.4264e-06 - val_WeightedF1: 0.0011
# Learning Rate: 0.00026572052738629284
# Epoch 6/10
# 1095/1095 [==============================] - 124s 114ms/step - loss: 0.2803 - Recall: 0.0529 - PrecisionAt1: 0.0802 - PrecisionAt3: 0.0686 - PrecisionAt5: 0.0646 - PrecisionAt10: 0.0570 - MicroF1: 0.0426 - MacroF1: 4.5539e-04 - WeightedF1: 0.0497 - val_loss: 0.2057 - val_Recall: 0.0382 - val_PrecisionAt1: 0.3015 - val_PrecisionAt3: 0.1613 - val_PrecisionAt5: 0.1308 - val_PrecisionAt10: 0.0908 - val_MicroF1: 0.0703 - val_MacroF1: 4.6116e-05 - val_WeightedF1: 0.0338
# Learning Rate: 0.00023914847988635302
# Epoch 7/10
# 1095/1095 [==============================] - 124s 114ms/step - loss: 0.2082 - Recall: 0.0529 - PrecisionAt1: 0.0773 - PrecisionAt3: 0.0688 - PrecisionAt5: 0.0654 - PrecisionAt10: 0.0584 - MicroF1: 0.0430 - MacroF1: 4.5002e-04 - WeightedF1: 0.0500 - val_loss: 0.1697 - val_Recall: 0.0088 - val_PrecisionAt1: 0.1249 - val_PrecisionAt3: 0.1466 - val_PrecisionAt5: 0.1117 - val_PrecisionAt10: 0.0808 - val_MicroF1: 0.0170 - val_MacroF1: 3.1101e-05 - val_WeightedF1: 0.0136
# Learning Rate: 0.00021523362665902825
# Epoch 8/10
# 1095/1095 [==============================] - 125s 114ms/step - loss: 0.1727 - Recall: 0.0525 - PrecisionAt1: 0.0742 - PrecisionAt3: 0.0671 - PrecisionAt5: 0.0639 - PrecisionAt10: 0.0574 - MicroF1: 0.0435 - MacroF1: 4.3377e-04 - WeightedF1: 0.0501 - val_loss: 0.1218 - val_Recall: 0.0091 - val_PrecisionAt1: 0.2339 - val_PrecisionAt3: 0.1675 - val_PrecisionAt5: 0.1376 - val_PrecisionAt10: 0.0947 - val_MicroF1: 0.0176 - val_MacroF1: 3.4073e-05 - val_WeightedF1: 0.0149
# Learning Rate: 0.00019371026137378068
# Epoch 9/10
# 1095/1095 [==============================] - 124s 114ms/step - loss: 0.1221 - Recall: 0.0520 - PrecisionAt1: 0.0750 - PrecisionAt3: 0.0693 - PrecisionAt5: 0.0662 - PrecisionAt10: 0.0596 - MicroF1: 0.0441 - MacroF1: 4.5427e-04 - WeightedF1: 0.0505 - val_loss: 0.0951 - val_Recall: 0.0554 - val_PrecisionAt1: 0.3122 - val_PrecisionAt3: 0.1694 - val_PrecisionAt5: 0.1271 - val_PrecisionAt10: 0.0972 - val_MicroF1: 0.0955 - val_MacroF1: 5.5880e-05 - val_WeightedF1: 0.0358
# Learning Rate: 0.00017433923785574736
# Epoch 10/10
# 1095/1095 [==============================] - 125s 114ms/step - loss: 0.1040 - Recall: 0.0512 - PrecisionAt1: 0.0756 - PrecisionAt3: 0.0696 - PrecisionAt5: 0.0662 - PrecisionAt10: 0.0590 - MicroF1: 0.0442 - MacroF1: 4.5575e-04 - WeightedF1: 0.0504 - val_loss: 0.0904 - val_Recall: 0.0485 - val_PrecisionAt1: 0.0998 - val_PrecisionAt3: 0.1210 - val_PrecisionAt5: 0.1352 - val_PrecisionAt10: 0.0937 - val_MicroF1: 0.0687 - val_MacroF1: 7.0355e-05 - val_WeightedF1: 0.0231

# %%
# Plot the Recall metric at each itteration
plt.plot(result.history['Recall'], label='train_Recall');
plt.plot(result.history['val_Recall'], label='val_Recall');
plt.legend();

# %%
# Plot the PrecisionAt1 metric at each itteration
plt.plot(result.history['PrecisionAt1'], label='train_PrecisionAt1');
plt.plot(result.history['val_PrecisionAt1'], label='val_PrecisionAt1');
plt.legend();

# %%
# Plot the PrecisionAt3 metric at each itteration
plt.plot(result.history['PrecisionAt3'], label='train_PrecisionAt3l');
plt.plot(result.history['val_PrecisionAt3'], label='val_PrecisionAt3');
plt.legend();

# %%
# Plot the PrecisionAt5 metric at each itteration
plt.plot(result.history['PrecisionAt5'], label='train_PrecisionAt5');
plt.plot(result.history['val_PrecisionAt5'], label='val_PrecisionAt5');
plt.legend();

# %%
# Plot the PrecisionAt10 metric at each itteration
plt.plot(result.history['PrecisionAt10'], label='train_PrecisionAt10');
plt.plot(result.history['val_PrecisionAt10'], label='val_PrecisionAt10');
plt.legend();

# %%
# Plot the MicroF1 metric at each itteration
plt.plot(result.history['MicroF1'], label='train_MicroF1');
plt.plot(result.history['val_MicroF1'], label='val_MicroF1');
plt.legend();

# %%
# Plot the MacroF1 metric at each itteration
plt.plot(result.history['MacroF1'], label='train_MacroF1');
plt.plot(result.history['val_MacroF1'], label='val_MacroF1');
plt.legend();

# %%
# Plot the WeightedF1 metric at each itteration
plt.plot(result.history['WeightedF1'], label='train_WeightedF1');
plt.plot(result.history['val_WeightedF1'], label='val_WeightedF1');
plt.legend();
