# %%
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.2)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %% [markdown]
# # Create document embeddings by averaging word embeddings

# %%
# Import the libraries
import os
import numpy as np
from numpy import load
from scipy.sparse import load_npz
import tensorflow as tf
from tensorflow.keras.mixed_precision import experimental as mixed_precision
from tensorflow.keras.layers import Input, Conv1D, GlobalMaxPooling1D, concatenate, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Precision, Recall
from tensorflow_addons.metrics import F1Score
import matplotlib.pyplot as plt

# %%
# Check that a GPU is available
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Not sure why, but I need this to get TF to work
# from: https://www.tensorflow.org/guide/gpu#limiting_gpu_memory_growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ### Load in the data

# %%
# Define the load path
load_path = '../Datasets/AmazonCat-13K/processed/'

# %%
# Load the X_train
X_train_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_train_averaged.npz', allow_pickle=True)
X_train = list(X_train_data['arr_0'])

# %%
# Load the X_test
X_test_data = load('../Datasets/AmazonCat-13K/processed/' + 'X_test_averaged.npz', allow_pickle=True)
X_test = list(X_test_data['arr_0'])

# %%
# Load y_train
y_train_sparse = load_npz(load_path + 'y_train_sparse_averaged.npz').astype('int64')

# %%
# Load y_test
y_test_sparse = load_npz(load_path + 'y_test_sparse_averaged.npz').astype('int64')

# %%
# Check the shape of the X data
print(f'X_train: ({len(X_train)}, {len(X_train[0])})')
print(f'X_test: ({len(X_test)}, {len(X_test[0])})')
# Out:
# X_train: (1120773, 101)
# X_test: (373591, 101)

# %%
# Check the shape of the y data
print(f'y_train: {y_train_sparse.shape}')
print(f'y_test: {y_test_sparse.shape}')
# Out:
# y_train: (1120773, 14295)
# y_test: (373591, 14295)

# %% [markdown]
# ### Create Sparse Tensors

# %%
# Create function to convert sparse matrix to SparseTensor
def convert_sparse_matrix_to_sparse_tensor(sparse_matrix):
    coo = sparse_matrix.tocoo()
    indices = np.mat([coo.row, coo.col]).transpose()
    return tf.SparseTensor(indices, coo.data, coo.shape)

# %%
# Create sparse tensor of y_train
y_train_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_train_sparse))

# %%
# Create sparse tensor of y_test
y_test_sparse_tensor = tf.sparse.reorder(convert_sparse_matrix_to_sparse_tensor(y_test_sparse))

# %% [markdown]
# ### Create the TensorFlow Dataset

# %%
# Create function to convert SparseTensor to dense tensor
def convert_sparse_tensor_to_dense_tensor(X, y_sparse):
    y_dense = tf.sparse.to_dense(y_sparse)
    return X, y_dense

# %%
# Create the train dataset
tr_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train_sparse_tensor))
tr_dataset = tr_dataset.map(convert_sparse_tensor_to_dense_tensor)
tr_dataset = tr_dataset.batch(batch_size=1024)

# %%
# Create the test dataset
val_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test_sparse_tensor))
val_dataset = val_dataset.map(convert_sparse_tensor_to_dense_tensor)
val_dataset = val_dataset.batch(batch_size=1024)

# %% [markdown]
# ### Define the model layers

# %%
# Define the perceptron architecture
i = Input(shape=len(X_train[0]), dtype=tf.int32)
x = Dense(units=len(X_train[0]), activation='relu')(i)
x = Dense(y_train_sparse.shape[1], activation='sigmoid')(x)

# %%
# Build the model
model = Model(i, x)

# %%
# Have a look at the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 101)]             0
# _________________________________________________________________
# dense (Dense)                (None, 101)               10302
# _________________________________________________________________
# dense_1 (Dense)              (None, 14295)             1458090
# =================================================================
# Total params: 1,468,392
# Trainable params: 1,468,392
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define how the model should be trained

# %%
# Define how the model should be trained
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.01), # CNN-Kim uses SGD with Adelta update rule
              loss='binary_crossentropy',
              metrics=[Recall(name='Recall'),
                       Precision(name='Precision'),
                       Precision(top_k=1, name='PrecisionAt1'),
                       Precision(top_k=3, name='PrecisionAt3'),
                       Precision(top_k=5, name='PrecisionAt5'),
                       Precision(top_k=10, name='PrecisionAt10'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='micro', 
                               threshold=0.5,
                               name='MicroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='macro', 
                               threshold=0.5,
                               name='MacroF1'),
                       F1Score(num_classes=y_train_sparse.shape[1], 
                               average='weighted', 
                               threshold=0.5,
                               name='WeightedF1')
                      ])

# %%
# Create learning rate decay function
def lr_scheduler(epoch, lr):
    learning_rate = lr * 0.9
    print(f'Learning Rate: {learning_rate}')
    return learning_rate

# define the learning rate scheduler
callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %% [markdown]
# ### Train the model

# %%
# Train the model
result = model.fit(tr_dataset,
                   epochs=20,
                   validation_data=val_dataset,
                   callbacks=[callback]);
# Out:
# Train for 1095 steps, validate for 365 steps
# Learning Rate: 0.008999999798834325
# Epoch 1/20
# 1095/1095 [==============================] - 128s 117ms/step - loss: 0.0042 - Recall: 0.2009 - Precision: 0.1285 - PrecisionAt1: 0.7493 - PrecisionAt3: 0.5143 - PrecisionAt5: 0.3868 - PrecisionAt10: 0.2455 - MicroF1: 0.1567 - MacroF1: 0.0043 - WeightedF1: 0.2409 - val_loss: 0.0013 - val_Recall: 0.2532 - val_Precision: 0.7663 - val_PrecisionAt1: 0.7971 - val_PrecisionAt3: 0.5726 - val_PrecisionAt5: 0.4358 - val_PrecisionAt10: 0.2765 - val_MicroF1: 0.3806 - val_MacroF1: 0.0087 - val_WeightedF1: 0.2979
# Learning Rate: 0.008099999651312828
# Epoch 2/20
# 1095/1095 [==============================] - 130s 119ms/step - loss: 0.0012 - Recall: 0.2728 - Precision: 0.7610 - PrecisionAt1: 0.8054 - PrecisionAt3: 0.5853 - PrecisionAt5: 0.4489 - PrecisionAt10: 0.2861 - MicroF1: 0.4016 - MacroF1: 0.0148 - WeightedF1: 0.3226 - val_loss: 0.0011 - val_Recall: 0.2824 - val_Precision: 0.7646 - val_PrecisionAt1: 0.8111 - val_PrecisionAt3: 0.5958 - val_PrecisionAt5: 0.4590 - val_PrecisionAt10: 0.2920 - val_MicroF1: 0.4125 - val_MacroF1: 0.0195 - val_WeightedF1: 0.3337
# Learning Rate: 0.007289999350905419
# Epoch 3/20
# 1095/1095 [==============================] - 129s 118ms/step - loss: 0.0011 - Recall: 0.2952 - Precision: 0.7604 - PrecisionAt1: 0.8146 - PrecisionAt3: 0.6012 - PrecisionAt5: 0.4650 - PrecisionAt10: 0.2967 - MicroF1: 0.4253 - MacroF1: 0.0261 - WeightedF1: 0.3486 - val_loss: 0.0011 - val_Recall: 0.2977 - val_Precision: 0.7639 - val_PrecisionAt1: 0.8167 - val_PrecisionAt3: 0.6058 - val_PrecisionAt5: 0.4690 - val_PrecisionAt10: 0.2987 - val_MicroF1: 0.4285 - val_MacroF1: 0.0295 - val_WeightedF1: 0.3516
# Learning Rate: 0.006560999248176813
# Epoch 4/20
# 1095/1095 [==============================] - 127s 116ms/step - loss: 0.0011 - Recall: 0.3076 - Precision: 0.7612 - PrecisionAt1: 0.8196 - PrecisionAt3: 0.6097 - PrecisionAt5: 0.4736 - PrecisionAt10: 0.3023 - MicroF1: 0.4382 - MacroF1: 0.0371 - WeightedF1: 0.3630 - val_loss: 0.0011 - val_Recall: 0.3078 - val_Precision: 0.7632 - val_PrecisionAt1: 0.8204 - val_PrecisionAt3: 0.6120 - val_PrecisionAt5: 0.4749 - val_PrecisionAt10: 0.3025 - val_MicroF1: 0.4387 - val_MacroF1: 0.0384 - val_WeightedF1: 0.3628
# Learning Rate: 0.005904899490997195
# Epoch 5/20
# 1095/1095 [==============================] - 129s 118ms/step - loss: 0.0011 - Recall: 0.3156 - Precision: 0.7624 - PrecisionAt1: 0.8230 - PrecisionAt3: 0.6153 - PrecisionAt5: 0.4790 - PrecisionAt10: 0.3059 - MicroF1: 0.4464 - MacroF1: 0.0473 - WeightedF1: 0.3722 - val_loss: 0.0011 - val_Recall: 0.3144 - val_Precision: 0.7635 - val_PrecisionAt1: 0.8229 - val_PrecisionAt3: 0.6162 - val_PrecisionAt5: 0.4788 - val_PrecisionAt10: 0.3050 - val_MicroF1: 0.4454 - val_MacroF1: 0.0466 - val_WeightedF1: 0.3705
# Learning Rate: 0.00531440949998796
# Epoch 6/20
# 1095/1095 [==============================] - 127s 116ms/step - loss: 0.0010 - Recall: 0.3211 - Precision: 0.7638 - PrecisionAt1: 0.8254 - PrecisionAt3: 0.6191 - PrecisionAt5: 0.4830 - PrecisionAt10: 0.3083 - MicroF1: 0.4521 - MacroF1: 0.0569 - WeightedF1: 0.3784 - val_loss: 0.0010 - val_Recall: 0.3192 - val_Precision: 0.7636 - val_PrecisionAt1: 0.8247 - val_PrecisionAt3: 0.6189 - val_PrecisionAt5: 0.4816 - val_PrecisionAt10: 0.3067 - val_MicroF1: 0.4502 - val_MacroF1: 0.0540 - val_WeightedF1: 0.3758
# Learning Rate: 0.004782968759536744
# Epoch 7/20
# 1095/1095 [==============================] - 128s 117ms/step - loss: 0.0010 - Recall: 0.3249 - Precision: 0.7653 - PrecisionAt1: 0.8274 - PrecisionAt3: 0.6220 - PrecisionAt5: 0.4858 - PrecisionAt10: 0.3101 - MicroF1: 0.4561 - MacroF1: 0.0652 - WeightedF1: 0.3828 - val_loss: 0.0010 - val_Recall: 0.3231 - val_Precision: 0.7632 - val_PrecisionAt1: 0.8262 - val_PrecisionAt3: 0.6210 - val_PrecisionAt5: 0.4835 - val_PrecisionAt10: 0.3079 - val_MicroF1: 0.4540 - val_MacroF1: 0.0602 - val_WeightedF1: 0.3798
# Learning Rate: 0.0043046717997640375
# Epoch 8/20
# 1095/1095 [==============================] - 124s 114ms/step - loss: 0.0010 - Recall: 0.3276 - Precision: 0.7667 - PrecisionAt1: 0.8292 - PrecisionAt3: 0.6243 - PrecisionAt5: 0.4880 - PrecisionAt10: 0.3114 - MicroF1: 0.4591 - MacroF1: 0.0730 - WeightedF1: 0.3861 - val_loss: 0.0010 - val_Recall: 0.3254 - val_Precision: 0.7636 - val_PrecisionAt1: 0.8273 - val_PrecisionAt3: 0.6227 - val_PrecisionAt5: 0.4852 - val_PrecisionAt10: 0.3090 - val_MicroF1: 0.4563 - val_MacroF1: 0.0653 - val_WeightedF1: 0.3823
# Learning Rate: 0.0038742044940590858
# Epoch 9/20
# 1095/1095 [==============================] - 124s 113ms/step - loss: 0.0010 - Recall: 0.3297 - Precision: 0.7681 - PrecisionAt1: 0.8304 - PrecisionAt3: 0.6262 - PrecisionAt5: 0.4899 - PrecisionAt10: 0.3125 - MicroF1: 0.4613 - MacroF1: 0.0802 - WeightedF1: 0.3885 - val_loss: 0.0010 - val_Recall: 0.3264 - val_Precision: 0.7650 - val_PrecisionAt1: 0.8280 - val_PrecisionAt3: 0.6241 - val_PrecisionAt5: 0.4864 - val_PrecisionAt10: 0.3098 - val_MicroF1: 0.4576 - val_MacroF1: 0.0696 - val_WeightedF1: 0.3836
# Learning Rate: 0.003486784128472209
# Epoch 10/20
# 1095/1095 [==============================] - 124s 114ms/step - loss: 0.0010 - Recall: 0.3314 - Precision: 0.7694 - PrecisionAt1: 0.8317 - PrecisionAt3: 0.6278 - PrecisionAt5: 0.4915 - PrecisionAt10: 0.3135 - MicroF1: 0.4632 - MacroF1: 0.0864 - WeightedF1: 0.3905 - val_loss: 0.0010 - val_Recall: 0.3269 - val_Precision: 0.7668 - val_PrecisionAt1: 0.8288 - val_PrecisionAt3: 0.6249 - val_PrecisionAt5: 0.4875 - val_PrecisionAt10: 0.3105 - val_MicroF1: 0.4584 - val_MacroF1: 0.0730 - val_WeightedF1: 0.3842
# Learning Rate: 0.003138105757534504
# Epoch 11/20
# 1095/1095 [==============================] - 124s 113ms/step - loss: 9.9729e-04 - Recall: 0.3327 - Precision: 0.7707 - PrecisionAt1: 0.8328 - PrecisionAt3: 0.6292 - PrecisionAt5: 0.4928 - PrecisionAt10: 0.3143 - MicroF1: 0.4648 - MacroF1: 0.0923 - WeightedF1: 0.3922 - val_loss: 0.0010 - val_Recall: 0.3275 - val_Precision: 0.7683 - val_PrecisionAt1: 0.8293 - val_PrecisionAt3: 0.6258 - val_PrecisionAt5: 0.4885 - val_PrecisionAt10: 0.3110 - val_MicroF1: 0.4593 - val_MacroF1: 0.0767 - val_WeightedF1: 0.3848
# Learning Rate: 0.0028242952656000854
# Epoch 12/20
# 1095/1095 [==============================] - 123s 112ms/step - loss: 9.9295e-04 - Recall: 0.3339 - Precision: 0.7719 - PrecisionAt1: 0.8336 - PrecisionAt3: 0.6305 - PrecisionAt5: 0.4940 - PrecisionAt10: 0.3151 - MicroF1: 0.4661 - MacroF1: 0.0973 - WeightedF1: 0.3936 - val_loss: 0.0010 - val_Recall: 0.3282 - val_Precision: 0.7689 - val_PrecisionAt1: 0.8302 - val_PrecisionAt3: 0.6265 - val_PrecisionAt5: 0.4893 - val_PrecisionAt10: 0.3116 - val_MicroF1: 0.4601 - val_MacroF1: 0.0799 - val_WeightedF1: 0.3854
# Learning Rate: 0.0025418657809495927
# Epoch 13/20
# 1095/1095 [==============================] - 122s 112ms/step - loss: 9.8919e-04 - Recall: 0.3349 - Precision: 0.7729 - PrecisionAt1: 0.8344 - PrecisionAt3: 0.6316 - PrecisionAt5: 0.4950 - PrecisionAt10: 0.3157 - MicroF1: 0.4673 - MacroF1: 0.1021 - WeightedF1: 0.3948 - val_loss: 0.0010 - val_Recall: 0.3291 - val_Precision: 0.7699 - val_PrecisionAt1: 0.8307 - val_PrecisionAt3: 0.6272 - val_PrecisionAt5: 0.4900 - val_PrecisionAt10: 0.3120 - val_MicroF1: 0.4611 - val_MacroF1: 0.0831 - val_WeightedF1: 0.3864
# Learning Rate: 0.0022876791190356016
# Epoch 14/20
# 1095/1095 [==============================] - 122s 112ms/step - loss: 9.8591e-04 - Recall: 0.3358 - Precision: 0.7738 - PrecisionAt1: 0.8351 - PrecisionAt3: 0.6325 - PrecisionAt5: 0.4960 - PrecisionAt10: 0.3163 - MicroF1: 0.4684 - MacroF1: 0.1067 - WeightedF1: 0.3959 - val_loss: 0.0010 - val_Recall: 0.3302 - val_Precision: 0.7705 - val_PrecisionAt1: 0.8311 - val_PrecisionAt3: 0.6280 - val_PrecisionAt5: 0.4907 - val_PrecisionAt10: 0.3125 - val_MicroF1: 0.4623 - val_MacroF1: 0.0859 - val_WeightedF1: 0.3877
# Learning Rate: 0.0020589112071320416
# Epoch 15/20
# 1095/1095 [==============================] - 122s 112ms/step - loss: 9.8303e-04 - Recall: 0.3366 - Precision: 0.7746 - PrecisionAt1: 0.8357 - PrecisionAt3: 0.6335 - PrecisionAt5: 0.4969 - PrecisionAt10: 0.3168 - MicroF1: 0.4693 - MacroF1: 0.1106 - WeightedF1: 0.3968 - val_loss: 0.0010 - val_Recall: 0.3312 - val_Precision: 0.7711 - val_PrecisionAt1: 0.8317 - val_PrecisionAt3: 0.6286 - val_PrecisionAt5: 0.4914 - val_PrecisionAt10: 0.3129 - val_MicroF1: 0.4634 - val_MacroF1: 0.0884 - val_WeightedF1: 0.3891
# Learning Rate: 0.0018530200235545636
# Epoch 16/20
# 1095/1095 [==============================] - 122s 111ms/step - loss: 9.8048e-04 - Recall: 0.3373 - Precision: 0.7754 - PrecisionAt1: 0.8363 - PrecisionAt3: 0.6342 - PrecisionAt5: 0.4976 - PrecisionAt10: 0.3173 - MicroF1: 0.4701 - MacroF1: 0.1139 - WeightedF1: 0.3976 - val_loss: 0.0010 - val_Recall: 0.3325 - val_Precision: 0.7711 - val_PrecisionAt1: 0.8322 - val_PrecisionAt3: 0.6292 - val_PrecisionAt5: 0.4919 - val_PrecisionAt10: 0.3132 - val_MicroF1: 0.4647 - val_MacroF1: 0.0903 - val_WeightedF1: 0.3907
# Learning Rate: 0.0016677180421538651
# Epoch 17/20
# 1095/1095 [==============================] - 121s 111ms/step - loss: 9.7821e-04 - Recall: 0.3379 - Precision: 0.7762 - PrecisionAt1: 0.8369 - PrecisionAt3: 0.6349 - PrecisionAt5: 0.4982 - PrecisionAt10: 0.3177 - MicroF1: 0.4708 - MacroF1: 0.1172 - WeightedF1: 0.3983 - val_loss: 0.0010 - val_Recall: 0.3340 - val_Precision: 0.7706 - val_PrecisionAt1: 0.8325 - val_PrecisionAt3: 0.6295 - val_PrecisionAt5: 0.4924 - val_PrecisionAt10: 0.3135 - val_MicroF1: 0.4660 - val_MacroF1: 0.0919 - val_WeightedF1: 0.3922
# Learning Rate: 0.0015009462484158575
# Epoch 18/20
# 1095/1095 [==============================] - 121s 110ms/step - loss: 9.7619e-04 - Recall: 0.3384 - Precision: 0.7768 - PrecisionAt1: 0.8373 - PrecisionAt3: 0.6356 - PrecisionAt5: 0.4988 - PrecisionAt10: 0.3180 - MicroF1: 0.4714 - MacroF1: 0.1204 - WeightedF1: 0.3990 - val_loss: 0.0010 - val_Recall: 0.3354 - val_Precision: 0.7694 - val_PrecisionAt1: 0.8327 - val_PrecisionAt3: 0.6299 - val_PrecisionAt5: 0.4926 - val_PrecisionAt10: 0.3137 - val_MicroF1: 0.4671 - val_MacroF1: 0.0930 - val_WeightedF1: 0.3935
# Learning Rate: 0.0013508516130968928
# Epoch 19/20
# 1095/1095 [==============================] - 122s 112ms/step - loss: 9.7438e-04 - Recall: 0.3389 - Precision: 0.7774 - PrecisionAt1: 0.8378 - PrecisionAt3: 0.6362 - PrecisionAt5: 0.4994 - PrecisionAt10: 0.3183 - MicroF1: 0.4720 - MacroF1: 0.1234 - WeightedF1: 0.3996 - val_loss: 0.0010 - val_Recall: 0.3367 - val_Precision: 0.7683 - val_PrecisionAt1: 0.8329 - val_PrecisionAt3: 0.6302 - val_PrecisionAt5: 0.4929 - val_PrecisionAt10: 0.3138 - val_MicroF1: 0.4682 - val_MacroF1: 0.0943 - val_WeightedF1: 0.3947
# Learning Rate: 0.0012157664517872036
# Epoch 20/20
# 1095/1095 [==============================] - 122s 112ms/step - loss: 9.7275e-04 - Recall: 0.3393 - Precision: 0.7779 - PrecisionAt1: 0.8382 - PrecisionAt3: 0.6368 - PrecisionAt5: 0.4999 - PrecisionAt10: 0.3186 - MicroF1: 0.4725 - MacroF1: 0.1259 - WeightedF1: 0.4001 - val_loss: 0.0010 - val_Recall: 0.3377 - val_Precision: 0.7676 - val_PrecisionAt1: 0.8330 - val_PrecisionAt3: 0.6304 - val_PrecisionAt5: 0.4932 - val_PrecisionAt10: 0.3139 - val_MicroF1: 0.4690 - val_MacroF1: 0.0952 - val_WeightedF1: 0.3955

# %%
# Plot the Recall metric at each itteration
plt.plot(result.history['Recall'], label='train_Recall');
plt.plot(result.history['val_Recall'], label='val_Recall');
plt.legend();

# %%
# Plot the Precision metric at each itteration
plt.plot(result.history['Precision'], label='train_Precision');
plt.plot(result.history['val_Precision'], label='val_Precision');
plt.legend();

# %%
# Plot the PrecisionAt1 metric at each itteration
plt.plot(result.history['PrecisionAt1'], label='train_PrecisionAt1');
plt.plot(result.history['val_PrecisionAt1'], label='val_PrecisionAt1');
plt.legend();

# %%
# Plot the PrecisionAt3 metric at each itteration
plt.plot(result.history['PrecisionAt3'], label='train_PrecisionAt3l');
plt.plot(result.history['val_PrecisionAt3'], label='val_PrecisionAt3');
plt.legend();

# %%
# Plot the PrecisionAt5 metric at each itteration
plt.plot(result.history['PrecisionAt5'], label='train_PrecisionAt5');
plt.plot(result.history['val_PrecisionAt5'], label='val_PrecisionAt5');
plt.legend();

# %%
# Plot the PrecisionAt10 metric at each itteration
plt.plot(result.history['PrecisionAt10'], label='train_PrecisionAt10');
plt.plot(result.history['val_PrecisionAt10'], label='val_PrecisionAt10');
plt.legend();

# %%
# Plot the MicroF1 metric at each itteration
plt.plot(result.history['MicroF1'], label='train_MicroF1');
plt.plot(result.history['val_MicroF1'], label='val_MicroF1');
plt.legend();

# %%
# Plot the MacroF1 metric at each itteration
plt.plot(result.history['MacroF1'], label='train_MacroF1');
plt.plot(result.history['val_MacroF1'], label='val_MacroF1');
plt.legend();

# %%
# Plot the WeightedF1 metric at each itteration
plt.plot(result.history['WeightedF1'], label='train_WeightedF1');
plt.plot(result.history['val_WeightedF1'], label='val_WeightedF1');
plt.legend();
