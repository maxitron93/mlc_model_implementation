# %% [markdown]
# # Create document embeddings
# We'll use the doc2vec module from gensim to create an embedding matrix that can be used by tensorflow

# %%
# Import the libraries
import pandas as pd
import numpy as np
import ast
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from sklearn import utils
from tensorflow.keras.preprocessing.text import Tokenizer
from gensim.models import Doc2Vec
from gensim.models.doc2vec import FAST_VERSION
from gensim.models.doc2vec import TaggedDocument
# Out:
# C:\Users\maxitron\Anaconda3\lib\site-packages\tqdm\std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# ### Load in the data

# %%
# Load in the data
# data_list = [a, b, c, d, e, f, g, h, i ,f] = [None, None, None, None, None, None, None, None, None, None]
data_list = [a] = [None]
data_location = '../Datasets/AmazonCat-13K/processed/' 
for i in range(len(data_list)):
    data_list[i] = pd.read_csv(data_location + f'first_pass_no{i + 1}.csv', encoding='latin1')
    
# Concatenate all the data and reset the index
data = pd.concat(data_list, sort=False)
data = data.reset_index()

# Delete unused var (to save memory)
del data_list

# %%
# Convert the labels from string to array (return unique values only)
data['labels'] = data['labels'].apply(lambda labels: list(set(ast.literal_eval(labels))))

# %%
# Drop rows with missing values
data = data.dropna(axis=0)

# %%
# Create function to join title and description
def join_title_and_description(row):
    return f'{row["title"]} {row["description"]}'

# %%
# Create a new column that combines the title and description
data['title_and_description'] = data.apply(lambda row: join_title_and_description(row), axis=1)

# %%
# Drop title and description columns (to save memory)
data = data.drop(labels=['title', 'description'], axis=1)

# %%
# Have a look at the shape
data.shape
# Out:
# (149446, 4)

# %%
# Have a look at the first 3 rows
data.head(n=3)
# Out:
#    index        item_id                                             labels  \
# 0      0  ID:B0027DQHA0                [Classical, Movies & TV, TV, Music]
# 1      1  ID:0756400120  [United States, Anthologies & Literary Collect...
# 2      2  ID:B00024YAOQ  [Business & Investing, Motivation & Self-Impro...
#
#                                title_and_description
# 0  Sao Paulo Samba (2008) Conducted by John Nesch...
# 1  Past Imperfect (Daw Book Collectors) This fast...
# 2  Winning Every Time: How to Use the Skills of a...

# %% [markdown]
# ### Tokenize the data

# %%
# Convert from df to list so it can be processed
text = data['title_and_description'].tolist()

# %%
# Tokenize the data
VOCAB_SIZE = 5000 
# VOCAB_SIZE = 200000
tokenizer = Tokenizer(num_words=VOCAB_SIZE)
tokenizer.fit_on_texts(text)

# %%
# Create a squence from the tokens
data['title_and_description'] = tokenizer.texts_to_sequences(text)

# %%
# Delete unused var (to save memory)
del text

# %%
# Have a look at the first sequence
print(data['title_and_description'].iloc[0])
# Out:
# [3280, 4417, 19, 239, 214, 1203, 1, 2950, 7, 2916, 19, 55, 3, 1999, 97, 127, 181, 1, 2950, 265, 304, 1, 3701, 9, 16, 1267, 3, 2, 1999, 97, 1474, 131, 498]

# %%
# Convert sequence of integers to sequence of tokens so they can be processed by Doc2vec
data['title_and_description'] = data['title_and_description'].apply(lambda seq: [tokenizer.index_word[index] for index in seq])

# %%
# Have a look at the first sequence
print(data['title_and_description'].iloc[0])
# Out:
# ['2008', 'conducted', 'by', 'john', 'since', '1997', 'the', 'orchestra', 'is', 'defined', 'by', 'its', 'of', 'latin', 'american', 'music', 'here', 'the', 'orchestra', 'yet', 'again', 'the', 'listener', 'with', 'an', 'selection', 'of', 'and', 'latin', 'american', 'classics', 'including', 'w']

# %% [markdown]
# ### Create the doc2vec vectors

# %%
# Check gensim version used
FAST_VERSION
# Out:
# 1

# %%
# Create the tagged documents
tagged_documents = data.apply(lambda row: TaggedDocument(words=row['title_and_description'], tags=row['labels']), axis=1)

# %%
# Have a look at the first tagged document
tagged_documents.values[0]
# Out:
# TaggedDocument(words=['2008', 'conducted', 'by', 'john', 'since', '1997', 'the', 'orchestra', 'is', 'defined', 'by', 'its', 'of', 'latin', 'american', 'music', 'here', 'the', 'orchestra', 'yet', 'again', 'the', 'listener', 'with', 'an', 'selection', 'of', 'and', 'latin', 'american', 'classics', 'including', 'w'], tags=['Classical', 'Movies & TV', 'TV', 'Music'])

# %%
# Define the doc2vec model
doc2vec_dbow = Doc2Vec(dm=0,            # 0 for Distributed Bag of Words, 1 for Distributed Memory
                       vector_size=200,  # Dimensionality of the feature vectors
                       window=5,        # The maximum distance between the current and predicted word within a sentence
                       negative=5,      # Specifies how many 'noise words' should be drawn
                       hs=0,            # If 1, hierarchical softmax will be used for model training. If set to 0, and negative is non-zero, negative sampling will be used.
                       min_count=2,     # Ignores all words with total frequency lower than this
                       sample=0,        # The threshold for configuring which higher-frequency words are randomly downsampled
                       alpha=0.025,     # Set the starting learning rate
                       min_alpha=0.025, # Set the minimum learning rate (linear decay)
                       workers=12)      # Use these many worker threads to train the model

# %%
# Build the vocabulary
doc2vec_dbow.build_vocab(tagged_documents.values)

# %%
# Train the model
for epoch in range(10):
    print(f'Training epoch {epoch + 1}')
    doc2vec_dbow.train(tagged_documents,
                       total_examples=len(tagged_documents.values),
                       epochs=1)
    doc2vec_dbow.alpha -= 0.002 # decrease the learning rate
    doc2vec_dbow.min_alpha = doc2vec_dbow.alpha # fix the learning rate, no decay
# Out:
# Training epoch 1
# Training epoch 2
# Training epoch 3
# Training epoch 4
# Training epoch 5
# Training epoch 6
# Training epoch 7
# Training epoch 8
# Training epoch 9
# Training epoch 10

# %%
doc2vec_dbow.docvecs.similarity('World War II', 'France')
# Out:
# 0.4677675

# %%
inferred_vector = doc2vec_dbow.infer_vector(['book', 'about', 'space', 'pirates', 'and', 'action'])

# %%
doc2vec_dbow.docvecs.most_similar([inferred_vector], topn=len(doc2vec_dbow.docvecs))
# Out:
# [('Pickle & Olive Forks', 0.6003987193107605),
#  ('Differential Covers', 0.5919567346572876),
#  ('Egg Noodles', 0.5796162486076355),
#  ('Gun Stock Accessories', 0.5733641386032104),
#  ('Intake & Exhaust Manifold', 0.5717841386795044),
#  ('Technology', 0.5666373372077942),
#  ('Printer Tractors', 0.5610466003417969),
#  ('Gay & Lesbian', 0.5606696605682373),
#  ('Desk Caddies', 0.5597009658813477),
#  ('Historical Study & Educational Resources', 0.5571966171264648),
#  ('Art Knives & Blades', 0.5563797950744629),
#  ('Buffers & Polishing Machine Backing Plates', 0.5561999082565308),
#  ('England', 0.5561740398406982),
#  ('Lighting Products', 0.5549966096878052),
#  ('History & Theory', 0.5534413456916809),
#  ('History', 0.5528998374938965),
#  ('French Horn', 0.5528833866119385),
#  ('Ideologies & Doctrines', 0.5519598722457886),
#  ('Flowtron', 0.5517383217811584),
#  ('Psychology', 0.550269603729248),
#  ('Bait Traps', 0.5501764416694641),
#  ('Handguards', 0.5489562749862671),
#  ('Economics', 0.5477913618087769),
#  ('Machine Polishing Equipment', 0.5477610230445862),
#  ('Lower Conversion Gasket Sets', 0.545592188835144),
#  ('Finger Boards & Finger Bikes', 0.5443006753921509),
#  ('Business & Finance', 0.5433914661407471),
#  ('Hammock Stands', 0.5425910949707031),
#  ('Milling Machines', 0.5425724387168884),
#  ('Indoor Bowling', 0.5416666269302368),
#  ('Asia', 0.5409163236618042),
#  ('Scientists', 0.539983868598938),
#  ('Professionals & Academics', 0.5387746691703796),
#  ('Starting Blocks', 0.5386796593666077),
#  ('Cosmetic Organizers', 0.5385391712188721),
#  ('Expanding Files', 0.5376732349395752),
#  ('France', 0.5371923446655273),
#  ('World War II', 0.5370244979858398),
#  ('Commemorative Plates', 0.5360074043273926),
#  ('Stands & Hangers', 0.5346106886863708),
#  ('Shuffleboard', 0.5335612893104553),
#  ('Ribbons', 0.5319602489471436),
#  ('Nonfiction', 0.5307602286338806),
#  ('Ear Muffs', 0.5300400257110596),
#  ('Cultural', 0.52958744764328),
#  ('International & World Politics', 0.5295737981796265),
#  ('Ireland', 0.5295733213424683),
#  ('Shock & Vibration Control', 0.5288835763931274),
#  ('Russia', 0.5280811786651611),
#  ('United States', 0.5279971361160278),
#  ('O-Rings & O-Ring Kits', 0.527809739112854),
#  ('Fragrant Drawer Liners', 0.5273736715316772),
#  ('Upright Basses', 0.5273518562316895),
#  ('Popular Economics', 0.5271957516670227),
#  ('Human Geography', 0.5269865989685059),
#  ('Weaving Looms', 0.5267663598060608),
#  ('Public Contract', 0.5266508460044861),
#  ('Salad Utensils', 0.5246953964233398),
#  ('Sociology', 0.5229923725128174),
#  ('Fur & Faux Fur', 0.5225554704666138),
#  ('Social Sciences', 0.5222501754760742),
#  ('Vibration Damping Mounts', 0.5216452479362488),
#  ('Religious Studies', 0.5215384364128113),
#  ('Steering Wheel Spinners', 0.5215180516242981),
#  ('Regional U.S.', 0.5199331045150757),
#  ('Exhaust Tools', 0.5198899507522583),
#  ('Pycnogenol', 0.5198056697845459),
#  ('18th Century', 0.5196385383605957),
#  ('Middle East', 0.5189299583435059),
#  ('History of Religion', 0.5181628465652466),
#  ('Bumper Hitch', 0.5177578926086426),
#  ('Emblems', 0.5176413059234619),
#  ('Chimney Brushes', 0.5176270604133606),
#  ('Whirlpool Bathtubs', 0.5174256563186646),
#  ('Specific Topics', 0.5167222023010254),
#  ('Politics & Government', 0.5164246559143066),
#  ('Oat Bran', 0.5163673162460327),
#  ('Wipe Holders', 0.5162819027900696),
#  ('Law', 0.516112744808197),
#  ('Leaders & Notable People', 0.5159354209899902),
#  ('Light Type', 0.5158272981643677),
#  ('Government', 0.5151388049125671),
#  ('Anthropology', 0.514726996421814),
#  ('Gear Boxes', 0.5129565000534058),
#  ('Shuttlecocks', 0.5129431486129761),
#  ('Pillars', 0.5124261379241943),
#  ('Baked', 0.5122190713882446),
#  ('Americas', 0.5121300220489502),
#  ('Table Tennis Sets', 0.5118302702903748),
#  ('Swags', 0.5116473436355591),
#  ('China', 0.5115693807601929),
#  ('Wreaths', 0.5111965537071228),
#  ('Public Affairs & Policy', 0.5110832452774048),
#  ('Screen Savers', 0.5108358860015869),
#  ('Bugles', 0.5099794864654541),
#  ('Hot & Cold Therapy', 0.5090505480766296),
#  ('International Relations', 0.5088167786598206),
#  ('Tableware', 0.5083978176116943),
#  ('Swim Noodles', 0.5082136988639832),
#  ('Christianity', 0.508022665977478),
#  ('Theater', 0.5078239440917969),
#  ('Angle Brooms', 0.5075382590293884),
#  ('Ethnic Studies', 0.507495641708374),
#  ('Starter Balls & Bats', 0.5074009299278259),
#  ('Metering Parts', 0.5073773860931396),
#  ('Art', 0.5069262385368347),
#  ('Economic Conditions', 0.5064934492111206),
#  ('Paddle Accessories', 0.5057398676872253),
#  ('19th Century', 0.5057069659233093),
#  ('Australia & Oceania', 0.5053126215934753),
#  ('Civil War', 0.5050937533378601),
#  ('Grips & Tapes', 0.5046460032463074),
#  ('Swim Caps', 0.5045719742774963),
#  ('Air Bypass Valves', 0.5039517283439636),
#  ('Wind & Rain', 0.5039318203926086),
#  ('Asian', 0.5038823485374451),
#  ('Poker Tables', 0.5036189556121826),
#  ('Ginger Snaps', 0.5031031370162964),
#  ('Political Science', 0.5024612545967102),
#  ('Fast-Pitch Softball Bats', 0.5023565888404846),
#  ('Social Services & Welfare', 0.5023255944252014),
#  ('Behavioral Sciences', 0.5018386840820312),
#  ('Tackle Storage Trays', 0.5015928149223328),
#  ('Floor-Standing Fountains', 0.501462459564209),
#  ('Bassoon', 0.5014460682868958),
#  ('Plastic Bats', 0.5012772083282471),
#  ('Layette Sets', 0.5012189149856567),
#  ('Lafuma', 0.5003348588943481),
#  ('Wales', 0.5002148151397705),
#  ('Social Policy', 0.5000958442687988),
#  ('Poker Layouts', 0.5000232458114624),
#  ('Research', 0.5000160932540894),
#  ('Computers & Technology', 0.5000001192092896),
#  ('Waterpainting Kits', 0.4996345043182373),
#  ('Sticks', 0.49950581789016724),
#  ('Business', 0.4989892840385437),
#  ('Sega Master System', 0.49893879890441895),
#  ('Shower Curtain Rings', 0.49883973598480225),
#  ('Religious & Liturgical', 0.49874401092529297),
#  ('World Literature', 0.49861282110214233),
#  ('Black Light Bulbs', 0.4986054301261902),
#  ('Political', 0.49837374687194824),
#  ('Expansion Chambers', 0.49825212359428406),
#  ('Almond Butter', 0.4977554380893707),
#  ('Gay', 0.4971163868904114),
#  ('Professional & Technical', 0.49699780344963074),
#  ('Condensers', 0.4965704381465912),
#  ('Religious', 0.4961722493171692),
#  ('Cuticle Pushers', 0.4960578382015228),
#  ('Tackle Storage Bags', 0.49579083919525146),
#  ('Sumac', 0.49554312229156494),
#  ('Legal Theory & Systems', 0.4952087998390198),
#  ('Flange', 0.4951664209365845),
#  ('Sex', 0.4950586259365082),
#  ('Theology', 0.4941244423389435),
#  ('Storage Drawer Units', 0.4940899908542633),
#  ('Essays & Correspondence', 0.49361974000930786),
#  ('Biographies', 0.49347978830337524),
#  ('Ice Makers', 0.4933469295501709),
#  ('Medicine', 0.49332937598228455),
#  ('Turmeric', 0.49311363697052),
#  ('Education & Reference', 0.4925207495689392),
#  ('Philosophy', 0.4924241602420807),
#  ('Algebraic Geometry', 0.49212825298309326),
#  ('Military Science', 0.49156108498573303),
#  ('Cowbells', 0.4907453656196594),
#  ('Ratcheting Cargo Bars', 0.49016520380973816),
#  ('Gun Lubrication', 0.4901469945907593),
#  ('Accounting & Finance', 0.4898809492588043),
#  ('Crash-Ride', 0.48971909284591675),
#  ('Cassettes & Freewheels', 0.4890703558921814),
#  ('Presidents & Heads of State', 0.4889971911907196),
#  ('Bicycle Carriers', 0.48894745111465454),
#  ('Reference', 0.4887112081050873),
#  ('Hem Tape', 0.48865434527397156),
#  ('Notions', 0.4882926344871521),
#  ('Charcoal Air Purifiers', 0.48816633224487305),
#  ('Anthologies & Literary Collections', 0.48804277181625366),
#  ('Ethics', 0.4878445565700531),
#  ('Human Rights', 0.4877714514732361),
#  ('Geometry & Topology', 0.48776528239250183),
#  ('Paper Roll Cutters', 0.48747074604034424),
#  ('Lasers', 0.4871322810649872),
#  ('Toilet Tanks', 0.4867589771747589),
#  ('Aesthetics', 0.48660916090011597),
#  ('Compressor Clutches', 0.4865764081478119),
#  ('Chile Paste', 0.48640796542167664),
#  ('Handlebar Bags', 0.4861483573913574),
#  ('Strap Locks', 0.48609912395477295),
#  ('United States Civil War', 0.48562848567962646),
#  ('Vibration Dampeners', 0.48561254143714905),
#  ('External Floppy Drives', 0.48489290475845337),
#  ('Biographies & Memoirs', 0.4847618341445923),
#  ('Sais', 0.4845162630081177),
#  ('Korea', 0.48443156480789185),
#  ('Clotheslines', 0.4842137098312378),
#  ('India', 0.48413705825805664),
#  ('Pucks', 0.4835893511772156),
#  ('Mini Table Games', 0.48354974389076233),
#  ('Multifunction Writing Instruments', 0.4835474491119385),
#  ('Flag Football Belts', 0.48354217410087585),
#  ('Pond Décor', 0.483488529920578),
#  ('Social History', 0.4833221137523651),
#  ('Tights & Hosiery', 0.48332056403160095),
#  ('Adhesive Removers', 0.4832545220851898),
#  ('Macroeconomics', 0.4831540286540985),
#  ('Nitrous Kits', 0.4827466309070587),
#  ("Women's Studies", 0.4827333390712738),
#  ('Italy', 0.48259514570236206),
#  ('Sharps Containers & Needle Destruction', 0.4819205105304718),
#  ('Laundry Baskets', 0.47226712107658386),
#  ('Medical Books', 0.4721200466156006),
#  ('Incense Holders', 0.471895307302475),
#  ('Bathroom Trays', 0.47178757190704346),
#  ('Southeast Asia', 0.47173693776130676),
#  ('Rack Attachments', 0.4716928005218506),
#  ('3D Glasses', 0.4716859459877014),
#  ('Entertainers', 0.47095876932144165),
#  ('Engineering', 0.47076570987701416),
#  ('Kindle Store', 0.47075116634368896),
#  ('Nature & Ecology', 0.47071224451065063),
#  ('Alternative & Holistic', 0.47054821252822876),
#  ('Emergency & Safety Equipment', 0.47008800506591797),
#  ('Accounting', 0.4699804186820984),
#  ('Abrasive Mounted Points', 0.4698258936405182),
#  ('Aviation', 0.4697272777557373),
#  ('Western', 0.46972471475601196),
#  ('Ice Tongs', 0.46970880031585693),
#  ('Medicine & Health Sciences', 0.46938711404800415),
#  ('Refillable Containers', 0.4693644642829895),
#  ('Art History', 0.46915531158447266),
#  ('Public Affairs & Administration', 0.46870067715644836),
#  ('Pre-Heater', 0.468574196100235),
#  ('Arts & Photography', 0.468557745218277),
#  ('Economic Policy & Development', 0.4682020843029022),
#  ('Blotting Paper', 0.4680511951446533),
#  ('Groin Protectors', 0.46799635887145996),
#  ('Money', 0.467856228351593),
#  ('Tassels', 0.46756306290626526),
#  ('Pogo Sticks', 0.46756237745285034),
#  ('Composers & Musicians', 0.46739816665649414),
#  ('Expansion Plugs', 0.4672733545303345),
#  ('Bar Strainers', 0.4670097231864929),
#  ('World War I', 0.4669678807258606),
#  ('Tarts', 0.46656978130340576),
#  ('Balaclavas', 0.4662955403327942),
#  ('Transportation', 0.4662601947784424),
#  ('Bat Accessories', 0.46602463722229004),
#  ('Writing', 0.46593886613845825),
#  ('Coyote', 0.46583855152130127),
#  ('Politics & Social Sciences', 0.4658087491989136),
#  ('Project Plans', 0.4654688835144043),
#  ('Xylophones', 0.46542632579803467),
#  ('Networking', 0.4651937782764435),
#  ('Sexuality', 0.4651886820793152),
#  ('Furniture Legs', 0.4649397134780884),
#  ('Pacifiers', 0.4649220407009125),
#  ('Greece', 0.4648878574371338),
#  ('Finger Cymbals', 0.4644659757614136),
#  ('TurboGrafx 16', 0.46439820528030396),
#  ('Laundry & Kitchen', 0.4641325771808624),
#  ('Amateur Production', 0.4640858769416809),
#  ('Revolution & Founding', 0.46408379077911377),
#  ('Candlesnuffers', 0.4640587568283081),
#  ("Children's Rooms", 0.4639674723148346),
#  ('Mathematics', 0.463919073343277),
#  ('20th Century', 0.4638936221599579),
#  ('Military & Wars', 0.4638564884662628),
#  ('Reamers', 0.46380776166915894),
#  ('Pond Liners & Seals', 0.46343421936035156),
#  ('17th Century', 0.46328863501548767),
#  ('Empty Fuel Bottles', 0.46313607692718506),
#  ('Bedpans', 0.46302539110183716),
#  ('Historiography', 0.4629010856151581),
#  ('Abolition', 0.46281683444976807),
#  ('Vanity Mirrors', 0.46265438199043274),
#  ('Schrodt Designs', 0.46256572008132935),
#  ('Military Sciences', 0.46250760555267334),
#  ('New', 0.46246030926704407),
#  ('Thermos', 0.4624204635620117),
#  ('Padfolio Ring Binders', 0.4622935950756073),
#  ('True Crime', 0.4621860682964325),
#  ('Shoe Covers', 0.46212294697761536),
#  ('North', 0.4619429111480713),
#  ('Leaf Springs', 0.46162256598472595),
#  ('Management Science', 0.4614522457122803),
#  ('Mental Illness', 0.46139031648635864),
#  ('Magnets', 0.46136748790740967),
#  ('Industrial', 0.4612099230289459),
#  ('Power & Ground Cable', 0.4611184000968933),
#  ('Labor & Industrial Relations', 0.4611050486564636),
#  ('Programming', 0.46103203296661377),
#  ('Straight', 0.46095752716064453),
#  ('Finance', 0.4608616232872009),
#  ('Taper Pins', 0.4608362913131714),
#  ('Psychology & Counseling', 0.460816890001297),
#  ('Peds & Liners', 0.4606286287307739),
#  ('Women in History', 0.4605105519294739),
#  ('Self-Help', 0.46021780371665955),
#  ('Anatomy', 0.45948725938796997),
#  ('Eye Charts', 0.45942163467407227),
#  ('Carburetor Baffle Plate', 0.459297239780426),
#  ('Legal History', 0.4590805768966675),
#  ('Magnetic Hooks', 0.458821564912796),
#  ('French', 0.45862093567848206),
#  ('Hayes', 0.4581485390663147),
#  ('Slavery & Emancipation', 0.45813310146331787),
#  ('Database Design', 0.45806097984313965),
#  ('Physics', 0.45800352096557617),
#  ('Burner Rings', 0.4579728841781616),
#  ('Naval', 0.4579470157623291),
#  ('Nut Crackers', 0.45789992809295654),
#  ('Fan Packs', 0.457893967628479),
#  ('Fly Tying Equipment', 0.45777082443237305),
#  ('Bookmarks', 0.4575401544570923),
#  ('Cubicle Hooks', 0.4575396180152893),
#  ('Manufacturing & Operational Systems', 0.4574885964393616),
#  ('Curlers', 0.45748329162597656),
#  ('Vegetable Relishes', 0.45745331048965454),
#  ('Surfing Fins', 0.45728611946105957),
#  ('City Planning & Urban Development', 0.45719558000564575),
#  ('Environmental Economics', 0.4571688771247864),
#  ('Poverty', 0.4570615589618683),
#  ('National', 0.45695292949676514),
#  ('Thermometer Accessories', 0.456943154335022),
#  ('Gun Magazine Pouches', 0.4568437337875366),
#  ('Mop Handles', 0.45670050382614136),
#  ('Information Management', 0.45669013261795044),
#  ('Dictionaries & Thesauruses', 0.45666414499282837),
#  ('Regents', 0.4565865397453308),
#  ('Garden Decor', 0.45647484064102173),
#  ('Drain Catches', 0.4564433991909027),
#  ('Pool Brushes', 0.4564380347728729),
#  ('Securities', 0.4562695026397705),
#  ('Gender Studies', 0.4561486542224884),
#  ('Lots', 0.4560733437538147),
#  ('Dusting Supplies', 0.4559558928012848),
#  ('Female Urinals', 0.45578405261039734),
#  ('Photo Adapters', 0.45565733313560486),
#  ('Mormonism', 0.45550936460494995),
#  ('Linguistics', 0.45550328493118286),
#  ('History & Philosophy', 0.45532360672950745),
#  ('Strut Compressors', 0.45524364709854126),
#  ('Heat Wrap', 0.45519864559173584),
#  ('Lamp Oil', 0.4551808834075928),
#  ('Computer Science', 0.45512035489082336),
#  ('Ethnic & Tribal', 0.45511430501937866),
#  ('Consciousness & Thought', 0.4548450708389282),
#  ('Power Door Lock', 0.45484423637390137),
#  ('Sierra Leone', 0.4548269808292389),
#  ('Conservatism & Liberalism', 0.4547244608402252),
#  ('Dice', 0.45455074310302734),
#  ('International', 0.454373300075531),
#  ('Feminist Theory', 0.4543707072734833),
#  ('Ice Augers', 0.45434778928756714),
#  ('Acetaminophen', 0.45431703329086304),
#  ('History & Criticism', 0.4541332721710205),
#  ('Short Story Collections', 0.45412224531173706),
#  ('Software', 0.45407581329345703),
#  ('Politics & State', 0.45406344532966614),
#  ('Educational Psychology', 0.4540598392486572),
#  ('Development & Growth', 0.4539996087551117),
#  ('Sigmund', 0.45398086309432983),
#  ('EGR Time Delay', 0.4539714753627777),
#  ('Top Tab Classification Folders', 0.45394769310951233),
#  ('Ecology', 0.4537142813205719),
#  ('Freud', 0.45360445976257324),
#  ('Standard Bases', 0.4534246623516083),
#  ('Bird', 0.4533912241458893),
#  ('Law Enforcement', 0.4531775712966919),
#  ('Interpersonal Relations', 0.4530985653400421),
#  ('Judaism', 0.45306718349456787),
#  ('Correction Fluid', 0.4530315697193146),
#  ('Stretch Film', 0.45290330052375793),
#  ('Irish', 0.45282354950904846),
#  ('Special Topics', 0.4528009593486786),
#  ('Constitutional Law', 0.4526836574077606),
#  ('Sewing Machine Needles', 0.45260918140411377),
#  ('Electrodes', 0.45257049798965454),
#  ('Church History', 0.4524904191493988),
#  ('Cognitive Psychology', 0.45242172479629517),
#  ('Sweet & Sour Sauce', 0.4523542821407318),
#  ('Chucking Reamers', 0.4521724581718445),
#  ('Collets', 0.45215538144111633),
#  ('Geography', 0.452123761177063),
#  ('China & Effect', 0.4520411491394043),
#  ('Exploration', 0.4520360827445984),
#  ('Toilet Lid & Tank Covers', 0.4519367516040802),
#  ('Calipers With Pads', 0.4516812860965729),
#  ('Small Business & Entrepreneurship', 0.45147567987442017),
#  ('Nature Writing', 0.4513382613658905),
#  ('Finger Moisteners', 0.45110416412353516),
#  ('Buttons & Pins', 0.45107007026672363),
#  ('Permanent Filters', 0.4508911967277527),
#  ('Science & Technology', 0.45083239674568176),
#  ('Alternate History', 0.4508275091648102),
#  ('Ski Storage Racks', 0.4507714509963989),
#  ('Burners', 0.450389564037323),
#  ('Australia', 0.4503838121891022),
#  ('Leadership', 0.45037955045700073),
#  ('Downriggers', 0.4503578543663025),
#  ('Lesbian', 0.4502258002758026),
#  ('Wind Socks', 0.45018988847732544),
#  ('Graphics & Multimedia', 0.45013463497161865),
#  ('International Business', 0.45003265142440796),
#  ('Brownies', 0.45000869035720825),
#  ('Toboggans', 0.4499710500240326),
#  ('Caribbean & Latin American', 0.4499396085739136),
#  ('Adaptive Telephones', 0.4499073326587677),
#  ('Ukulele Accessories', 0.44986292719841003),
#  ('Tap Lights', 0.4498523473739624),
#  ('Humanities', 0.4498198926448822),
#  ('Media Studies', 0.4497759938240051),
#  ('Ecotourism', 0.44973504543304443),
#  ('Lathes', 0.44967105984687805),
#  ('Europe', 0.4496263861656189),
#  ('Tourette Syndrome', 0.4496110677719116),
#  ('Emigrants & Immigrants', 0.44942617416381836),
#  ('Television', 0.4493682384490967),
#  ('British', 0.4492124021053314),
#  ('Safety & Assisting Rails', 0.4491809904575348),
#  ('Software Design & Engineering', 0.44914424419403076),
#  ('Replacement Blades', 0.4490349590778351),
#  ('Alternative Medicine', 0.44874611496925354),
#  ('Science & Math', 0.4486772119998932),
#  ('Photo Baseballs', 0.4485991597175598),
#  ('Civil Rights & Liberties', 0.44850894808769226),
#  ('TV Turntables', 0.4484953284263611),
#  ('AIDS', 0.4484785497188568),
#  ('Hydrometers', 0.44840994477272034),
#  ('FiberBuilt Umbrellas', 0.44825825095176697),
#  ('Jackson', 0.4481339156627655),
#  ('Bacon Bits', 0.44813352823257446),
#  ('Livestock Feeding & Watering Supplies', 0.44812458753585815),
#  ('Serving Forks', 0.4480742812156677),
#  ('Rivers', 0.44776463508605957),
#  ('Tuba', 0.44761914014816284),
#  ('External Frame Backpacks', 0.44759947061538696),
#  ('Fighting', 0.44759315252304077),
#  ('Geology Classroom Supplies', 0.447455495595932),
#  ('Hypnotherapy', 0.4473869800567627),
#  ('Combination Tables', 0.44730523228645325),
#  ('Wall-Hanging Fountains', 0.4472433924674988),
#  ('Slot Car Parts & Chassis', 0.4471878707408905),
#  ('Action & Adventure', 0.44712260365486145),
#  ('E-Collar Accessories', 0.4470853805541992),
#  ('Management & Leadership', 0.4469086229801178),
#  ('Social Scientists & Psychologists', 0.4468938708305359),
#  ('Cane Tips', 0.4468922019004822),
#  ('Wireless Jack Systems', 0.4468908905982971),
#  ('Travel', 0.44680529832839966),
#  ('Treadmill Motors', 0.44653937220573425),
#  ('Clasp Envelopes', 0.4464709758758545),
#  ('Overhead Video', 0.4462813436985016),
#  ('Library & Information Science', 0.44619011878967285),
#  ('Colonial Period', 0.44617873430252075),
#  ('Specialty Travel', 0.4460582137107849),
#  ('Conservation', 0.44602352380752563),
#  ('Photography', 0.446005642414093),
#  ('Skills', 0.4459887444972992),
#  ('Biology & Life Sciences', 0.44582104682922363),
#  ('Food Animal', 0.44564929604530334),
#  ('Fittings & Adapters', 0.4456024765968323),
#  ('Universal Joints', 0.44559159874916077),
#  ('Barbecue Tongs', 0.4455212354660034),
#  ('Berlin', 0.44530171155929565),
#  ('Book Stands', 0.44523221254348755),
#  ('Magnetic Pickups', 0.4452311396598816),
#  ('Java', 0.44517168402671814),
#  ('Business Ethics', 0.44513779878616333),
#  ('Exercise Machine Attachments', 0.4450019598007202),
#  ('Duratrel', 0.4449508786201477),
#  ('Paint Guns', 0.44486331939697266),
#  ('Bali', 0.44479942321777344),
#  ('Irish Coffee Glasses', 0.44472649693489075),
#  ('Literature', 0.44470149278640747),
#  ('Comparative Politics', 0.4446331858634949),
#  ('Sparkling Juice', 0.4446224570274353),
#  ('Race Relations', 0.4443747401237488),
#  ('Cultural Policy', 0.44420018792152405),
#  ('Disposable Wipes', 0.4441532790660858),
#  ('Heater', 0.44411346316337585),
#  ('Czech Republic', 0.4440453052520752),
#  ('Post Hole Diggers', 0.4440259039402008),
#  ('Keepsake Frames', 0.4439864158630371),
#  ('Grab Handles', 0.4438779652118683),
#  ('Other Media', 0.4437090754508972),
#  ('Client-Server Systems', 0.4436073899269104),
#  ('Other Religions', 0.44359901547431946),
#  ('Clinical', 0.4435739815235138),
#  ('Gun Loaders', 0.4435608685016632),
#  ('Reggae', 0.4435560703277588),
#  ('Holocaust', 0.4433111846446991),
#  ('Sponges & Wedges', 0.44322824478149414),
#  ('Psychological Thrillers', 0.4430714249610901),
#  ('Native American Studies', 0.44302093982696533),
#  ('Applicators', 0.44286319613456726),
#  ('Nixon', 0.442856103181839),
#  ('Portraits', 0.44276612997055054),
#  ('Urns', 0.4427468478679657),
#  ('Economic History', 0.4427230954170227),
#  ('Investments & Securities', 0.442669153213501),
#  ('Systems & Planning', 0.4425877332687378),
#  ('Truman', 0.44256219267845154),
#  ('Sugar Cane', 0.44253355264663696),
#  ('Themes', 0.4424937963485718),
#  ('Bow Maintenance Accessories', 0.44247230887413025),
#  ('Motorized Scooter Accessories', 0.44232285022735596),
#  ('Historical Study', 0.44231978058815),
#  ('Religion', 0.44226333498954773),
#  ('Baskets & Holders', 0.44220370054244995),
#  ('Popular Culture', 0.4421868324279785),
#  ('Trunks & Shorts', 0.4421253204345703),
#  ('Marching Tom-Toms', 0.44203639030456543),
#  ('Chain Tension Idlers', 0.4417486786842346),
#  ('Science', 0.44174519181251526),
#  ('Hose Repair Kits', 0.4416268765926361),
#  ('Coffee Scoops', 0.44160225987434387),
#  ('Letters & Correspondence', 0.4415947496891022),
#  ('Filler Necks', 0.4415760040283203),
#  ('Cutting Mats', 0.4415096342563629),
#  ('Echo Valley', 0.4415086805820465),
#  ('Business & Investing', 0.4414104223251343),
#  ('People of Color', 0.441405713558197),
#  ('Africa', 0.44136711955070496),
#  ('Caddies', 0.44135934114456177),
#  ('Software Development', 0.4413253664970398),
#  ('Criminology', 0.4411073327064514),
#  ('Bhutan', 0.4409918785095215),
#  ('Slides', 0.4409455955028534),
#  ('Indoor Ski Storage', 0.4407583475112915),
#  ('Sisters', 0.4407075345516205),
#  ('Spincasting Rods', 0.44068408012390137),
#  ('Expansion Valves', 0.4406210780143738),
#  ('Suspense', 0.4405428171157837),
#  ('Israel', 0.4405111074447632),
#  ('Sikhism', 0.44048482179641724),
#  ('Life & Institutions', 0.4404687285423279),
#  ('Cold-Meat Forks', 0.44037380814552307),
#  ('Natural History', 0.44035953283309937),
#  ('XML', 0.4402044415473938),
#  ('Football (American)', 0.44010689854621887),
#  ('Jerusalem', 0.44006186723709106),
#  ('Fishing Hats', 0.4396352767944336),
#  ('Russian & Former Soviet Union', 0.43961071968078613),
#  ('Head Gasket Sets', 0.4394254684448242),
#  ('Communication & Media Studies', 0.43939876556396484),
#  ('Golf Course GPS Units', 0.43939101696014404),
#  ('Nature', 0.43937191367149353),
#  ('Slipper Socks', 0.4393625259399414),
#  ('Aerospace', 0.43935883045196533),
#  ('Clinton', 0.43935734033584595),
#  ('Royalty', 0.4392958879470825),
#  ('Graphic Design', 0.43924659490585327),
#  ('Health', 0.43922027945518494),
#  ('Architects & Photographers', 0.439068466424942),
#  ('Used & Rental Textbooks', 0.4390007555484772),
#  ('Marzipan & Almond Paste', 0.4389740824699402),
#  ('Police Procedurals', 0.43888506293296814),
#  ('Australian', 0.4387570023536682),
#  ('Mopping Supplies', 0.4386782646179199),
#  ('American Literature', 0.43866071105003357),
#  ('Autoharp Accessories', 0.43859413266181946),
#  ('Disabled', 0.43854570388793945),
#  ('Spinning Tops', 0.43849968910217285),
#  ('Musical Genres', 0.4384487569332123),
#  ('Compulsive Behavior', 0.4383949637413025),
#  ('( J )', 0.4383752644062042),
#  ('Fusible Links', 0.43833979964256287),
#  ('Relationships', 0.43831682205200195),
#  ('Game Hardware', 0.43820247054100037),
#  ('Intelligence & Espionage', 0.43818020820617676),
#  ('Mauritius', 0.43815261125564575),
#  ('Bar Soaps', 0.43811821937561035),
#  ('Chemicals', 0.4380916655063629),
#  ('Fire Pit Accessories', 0.43807730078697205),
#  ('Puffs', 0.4380699694156647),
#  ('Treatment Packages', 0.438056081533432),
#  ('Eastern', 0.4379587769508362),
#  ('1900s', 0.43788212537765503),
#  ('Home D\x1acor Accents', 0.4378495216369629),
#  ('Data in the Enterprise', 0.4377501904964447),
#  ('Ouds', 0.43772265315055847),
#  ('Discuses', 0.43771401047706604),
#  ("Starters' Hearing Protectors", 0.43769556283950806),
#  ('Ancient', 0.4376133680343628),
#  ('Journalism & Nonfiction', 0.4375937879085541),
#  ('Environment & Ecology', 0.43752026557922363),
#  ('Modern (16th-21st Centuries)', 0.43750157952308655),
#  ('Regulation', 0.43742528557777405),
#  ('Lug Wrenches', 0.4373632073402405),
#  ('Rigging', 0.43723297119140625),
#  ('Stacking', 0.43719637393951416),
#  ('Computer Technology', 0.437162846326828),
#  ('Hardboard', 0.43714433908462524),
#  ('Flush Valves', 0.43707358837127686),
#  ('Stokes Select', 0.4370190501213074),
#  ('Power Cords', 0.4368860721588135),
#  ('Wool & Blends', 0.4367857873439789),
#  ('Rosin', 0.43675002455711365),
#  ('National & International Security', 0.4367057979106903),
#  ('Leg & Thigh Lifters', 0.43668970465660095),
#  ('Parents', 0.4366864562034607),
#  ('Over Door Hooks', 0.4366731345653534),
#  ('Card Playing', 0.43665993213653564),
#  ('Sexual Abuse', 0.43665003776550293),
#  ('Nephrology', 0.43660134077072144),
#  ('Languages & Tools', 0.43655434250831604),
#  ('High Tech', 0.4364680349826813),
#  ('Certification', 0.43645989894866943),
#  ('African-American & Black', 0.43639424443244934),
#  ('Printer Memory Modules', 0.436389684677124),
#  ('Plumbing Fittings', 0.4363085627555847),
#  ('Federal Government', 0.4362826943397522),
#  ('Hardware & Accessories', 0.43624982237815857),
#  ('Safety & First Aid Supplies', 0.4362388849258423),
#  ('Cake Supplies', 0.4361974596977234),
#  ('Wallace', 0.43613412976264954),
#  ('Under-Bed Storage', 0.4361298680305481),
#  ('Sandboxes & Accessories', 0.4359900951385498),
#  ('Crepe Pans', 0.435973584651947),
#  ('Elementary Education', 0.4359477460384369),
#  ('Exhaust Pipe Connector', 0.4358333349227905),
#  ('Shot Puts', 0.43581530451774597),
#  ('Veterans', 0.43571555614471436),
#  ('Nasal Strips', 0.4356722831726074),
#  ('Matting & Sleeving', 0.4356193244457245),
#  ('Loupes', 0.43561384081840515),
#  ('Architecture', 0.4354753792285919),
#  ('WetlandHunter', 0.4353087544441223),
#  ('Rich & Famous', 0.43519532680511475),
#  ('Ethics & Morality', 0.43517976999282837),
#  ('Methodology', 0.4351233243942261),
#  ('Cube Erasers', 0.4350927770137787),
#  ('Nature & How It Works', 0.4350317120552063),
#  ('Film & Television', 0.4349783957004547),
#  ('Straight Pins', 0.43497613072395325),
#  ('Korean War', 0.43497198820114136),
#  ('Fuel Leak Detectors', 0.434969037771225),
#  ('Tickets', 0.434948593378067),
#  ('Soy Sauce', 0.43490666151046753),
#  ('Kickballs', 0.4348897635936737),
#  ('Health Care Delivery', 0.43478602170944214),
#  ('Workplace', 0.4346088171005249),
#  ('Electric Erasers', 0.43448492884635925),
#  ('Brain', 0.43430763483047485),
#  ('Shelf Dividers', 0.43423083424568176),
#  ('Movements & Periods', 0.43422526121139526),
#  ('Splash Guards', 0.43419891595840454),
#  ('Power Conditioners', 0.43409717082977295),
#  ('Battery Packs & Chargers', 0.43408292531967163),
#  ('Seat Packs', 0.4338611960411072),
#  ('Movie Tie-Ins', 0.43356695771217346),
#  ('Spanish', 0.43348371982574463),
#  ('Piloting & Flight Instruction', 0.4334712028503418),
#  ('Top Tab Jackets & Pockets', 0.43342918157577515),
#  ('Terrorism', 0.4331662654876709),
#  ('Human Vision & Language Systems', 0.43309643864631653),
#  ('Specific Groups', 0.432818204164505),
#  ('Filter Cartridges', 0.4328107237815857),
#  ('Fletches', 0.43278616666793823),
#  ('Racing Seats', 0.43258222937583923),
#  ('Gear Bags', 0.432566374540329),
#  ('Potholders', 0.4323795735836029),
#  ('Psychoanalysis', 0.432341605424881),
#  ('Metal Detector Accessories', 0.43226635456085205),
#  ('Receiving Blankets', 0.43202948570251465),
#  ('Binder Pockets', 0.43180903792381287),
#  ('Bike Lube', 0.43174490332603455),
#  ('Industrial Process Filtration', 0.4317263662815094),
#  ('Tag Attacher Guns', 0.4317023456096649),
#  ('Graphics & Visualization', 0.43137285113334656),
#  ('Philosophers', 0.431368887424469),
#  ('Railings & Pickets', 0.4313625693321228),
#  ('Medical', 0.43127676844596863),
#  ('Labware', 0.4310852885246277),
#  ('Foils & Wraps', 0.4308888614177704),
#  ('Lifting Cushions', 0.43084558844566345),
#  ('Snowplows', 0.43083393573760986),
#  ('Administration & Medicine Economics', 0.43063443899154663),
#  ('Tropical Medicine', 0.4306291341781616),
#  ('BMX Equipment', 0.43062230944633484),
#  ('Visual Arts', 0.4305837154388428),
#  ('Electrical & Electronics', 0.43040329217910767),
#  ('Multigenerational', 0.43035972118377686),
#  ('Jumbo Playing Cards', 0.43020498752593994),
#  ('NFL', 0.4301767945289612),
#  ('Women Writers', 0.4301407039165497),
#  ('Binder Pouches', 0.42996904253959656),
#  ('Gift Wrap Bows', 0.4299682378768921),
#  ('Sewing Baskets', 0.4299547076225281),
#  ("Children's Studies", 0.42993003129959106),
#  ('( M )', 0.42992159724235535),
#  ('Rome Industries', 0.4297846555709839),
#  ('Motivational', 0.4297526478767395),
#  ('Mythology & Folk Tales', 0.4297153353691101),
#  ('Agricultural Sciences', 0.42968299984931946),
#  ('Confederacy', 0.4296687841415405),
#  ('Black Light Fixtures', 0.4296231269836426),
#  ('Australia & South Pacific', 0.4296061396598816),
#  ('Islam', 0.4295722246170044),
#  ('Diamond Accented', 0.42953675985336304),
#  ('Amazon Instant Video', 0.42947885394096375),
#  ('Geology', 0.42946940660476685),
#  ('Comparative Religion', 0.4294159412384033),
#  ('Kindle eBooks', 0.4290608763694763),
#  ('Three-in-One Commodes', 0.4290110468864441),
#  ('Mississippi', 0.4289875626564026),
#  ('Batons', 0.42889443039894104),
#  ('Divorce', 0.42883536219596863),
#  ('Activism', 0.42881953716278076),
#  ('Bibs', 0.4285699725151062),
#  ('Spacers & Adapters', 0.42853862047195435),
#  ('Arts & Literature', 0.4282284677028656),
#  ('Signal Path & Pedal Tuners', 0.4281808137893677),
#  ('Tire Steps', 0.4281148314476013),
#  ('Skiing & Snowboarding', 0.42805951833724976),
#  ('Fish Scales', 0.42802464962005615),
#  ('Machine Needles', 0.42802125215530396),
#  ('Environment', 0.42793992161750793),
#  ('Caviars & Roes', 0.4279356002807617),
#  ('Computers & Accessories', 0.42791685461997986),
#  ('SQL', 0.42780226469039917),
#  ('Mental Health', 0.42778995633125305),
#  ('Mangoes', 0.42778897285461426),
#  ('Points', 0.4277645945549011),
#  ('Developmental Psychology', 0.4275389313697815),
#  ('Chinese Star Anise', 0.427484393119812),
#  ('African Americans', 0.4272897243499756),
#  ('Shaft Nuts', 0.4271286725997925),
#  ('Thermostat Controllers', 0.4270792007446289),
#  ('Soap & Shampoo', 0.4268975853919983),
#  ('Egypt', 0.4268955588340759),
#  ('Epic', 0.426893025636673),
#  ('Baby Apparel', 0.42687857151031494),
#  ('Authors', 0.42687615752220154),
#  ('Church & State', 0.4268447458744049),
#  ('Electrolysis', 0.42678624391555786),
#  ('Weapons & Warfare', 0.42673832178115845),
#  ('Criticism & Theory', 0.4267151653766632),
#  ('Business Envelopes', 0.4266853928565979),
#  ('Cleats & Chocks', 0.4266372323036194),
#  ('Transaxle & Transmission', 0.42655736207962036),
#  ('Guides', 0.4264773428440094),
#  ('Rash Guards & UV Swimwear', 0.4264511466026306),
#  ('Henry VIII', 0.4264501929283142),
#  ('William', 0.4264264702796936),
#  ('Jefferson', 0.42639267444610596),
#  ('Gift Wrapping Supplies', 0.42638421058654785),
#  ('Nuclear Physics', 0.4263606071472168),
#  ('Direction & Production', 0.42629173398017883),
#  ('Patio Heater Covers', 0.4261949956417084),
#  ('Brushes & Dusters', 0.42619138956069946),
#  ('Teriyaki Sauce', 0.4261661171913147),
#  ('Cleaning Brushes', 0.42608875036239624),
#  ('Diplomacy', 0.42608386278152466),
#  ('Wreathmaking', 0.4260236322879791),
#  ('Food Tins', 0.4260215759277344),
#  ('Livestock Care', 0.42589879035949707),
#  ('Baby Floats', 0.4258492887020111),
#  ('Game Feeders', 0.42584097385406494),
#  ('Step 2', 0.4257335066795349),
#  ('Alberta', 0.42568546533584595),
#  ('Criticism', 0.4256798028945923),
#  ('Thermostat Housings', 0.42565029859542847),
#  ('Leaders & Tippet Materials', 0.42563724517822266),
#  ('Larry', 0.4256369471549988),
#  ('Nightgowns', 0.42559337615966797),
#  ('Concert Snare Drums', 0.42549842596054077),
#  ('Valve Stem Gasket Sets', 0.42545586824417114),
#  ('Strobe Lights', 0.42541125416755676),
#  ('Animal Behavior & Communication', 0.4254049062728882),
#  ('Biotechnology', 0.4253891706466675),
#  ('Speaker Grills', 0.42531487345695496),
#  ('Paint Strainers', 0.4252578914165497),
#  ('Leaders', 0.42507243156433105),
#  ('Alpine', 0.42499375343322754),
#  ('Saints', 0.42484816908836365),
#  ('Communication & Journalism', 0.4248464107513428),
#  ('Inflatable Bouncers', 0.42480796575546265),
#  ('Ukraine', 0.42479750514030457),
#  ('Swedish', 0.4247613251209259),
#  ('Bat Bags', 0.42473745346069336),
#  ('Interlocking Tape', 0.42456066608428955),
#  ('Kickboards', 0.42453694343566895),
#  ('Rainbow', 0.424356073141098),
#  ('Civil', 0.42424607276916504),
#  ('Tropical & Exotic Fruit', 0.42423778772354126),
#  ('Maritime', 0.42422711849212646),
#  ('White Wine Vinegars', 0.42412319779396057),
#  ('Lyndon', 0.4241221249103546),
#  ('Delphi', 0.4240671992301941),
#  ('Science Fiction', 0.42397239804267883),
#  ('Brake Lines', 0.4238179624080658),
#  ('Biology', 0.4237900376319885),
#  ('Heritage Farms', 0.4237365424633026),
#  ('Databases', 0.42373108863830566),
#  ('Citizenship', 0.42365163564682007),
#  ('Rack Accessories', 0.42364180088043213),
#  ('Computer Mousepads', 0.42359811067581177),
#  ('Archaeology', 0.42354366183280945),
#  ('Civil Rights', 0.423542320728302),
#  ('Outdoor Statues', 0.42351841926574707),
#  ('Canadian', 0.4234500825405121),
#  ('Nursing', 0.4234292507171631),
#  ('Animals', 0.4233783483505249),
#  ('False Nails', 0.4233154058456421),
#  ('Collections', 0.4231705665588379),
#  ('Filing Crates & Posting Tubs', 0.4230608344078064),
#  ('South', 0.42305421829223633),
#  ('Turkey', 0.42303478717803955),
#  ('Kettlebells', 0.4229750633239746),
#  ('Wildlife', 0.42295902967453003),
#  ('Values', 0.4228801131248474),
#  ('Domestic Life', 0.4228286147117615),
#  ('Drama', 0.4228198826313019),
#  ('Radio', 0.4227831959724426),
#  ('Single Authors', 0.42275723814964294),
#  ('Watercolor Paper', 0.42272698879241943),
#  ('Large Kitchen Bags', 0.42266082763671875),
#  ('Posting Tubs', 0.42254921793937683),
#  ('Outdoor Pennants', 0.4225471615791321),
#  ('Field Maintenance Equipment', 0.4225096106529236),
#  ('Cabinet Accessories', 0.42249801754951477),
#  ('Satire', 0.422484427690506),
#  ('Germany', 0.42247503995895386),
#  ('True Accounts', 0.4224032759666443),
#  ('Science & Mathematics', 0.4223194718360901),
#  ('Dropping Bottles', 0.42228618264198303),
#  ('Robert E.', 0.4222084879875183),
#  ('Brazil', 0.42213696241378784),
#  ('Counter Mats', 0.422091007232666),
#  ('Speedometer Cables', 0.42203980684280396),
#  ('Outdoor Heater Accessories', 0.42199116945266724),
#  ('Gravy & Sauce Ladles', 0.4219391942024231),
#  ('Decorative Canes', 0.421747088432312),
#  ('Comic Books', 0.42174074053764343),
#  ('Table Toppers', 0.42170625925064087),
#  ('Network Transceivers', 0.4216856360435486),
#  ('Literary Criticism', 0.4216381013393402),
#  ('Marriage', 0.4214636981487274),
#  ('Sandwich Spreads', 0.4214556813240051),
#  ('Udon', 0.42139145731925964),
#  ('Contemporary', 0.4212837219238281),
#  ('Ministry & Church Leadership', 0.4212709665298462),
#  ('Nail Repair', 0.4211818277835846),
#  ('Gender & Sexuality', 0.42114436626434326),
#  ('Individual Artists', 0.4211292266845703),
#  ('Dancers', 0.4210490584373474),
#  ('Oscillating Tools', 0.4210488796234131),
#  ('Criminal Law', 0.42099350690841675),
#  ('Lab Knives & Scalpels', 0.4209161102771759),
#  ('Pillow Inserts', 0.420846551656723),
#  ('Chainrings', 0.4208260774612427),
#  ('Dowel Pins', 0.4208149313926697),
#  ('Towel Bars', 0.42073068022727966),
#  ('Safelights', 0.42068588733673096),
#  ('Child', 0.4206755757331848),
#  ('Baking Soda', 0.42060545086860657),
#  ('Metaphysical', 0.42056429386138916),
#  ('Greenland', 0.4205493927001953),
#  ("Children's Books", 0.420535147190094),
#  ('Ninja Weapons', 0.42048919200897217),
#  ('Comic Fiction', 0.4204874634742737),
#  ('Fitness & Dieting', 0.42045658826828003),
#  ('Business & Management', 0.4203545153141022),
#  ('Blade Fuses', 0.42034703493118286),
#  ('Steam Generator Accessories', 0.420277863740921),
#  ('Film & Tape Dry Adhesives', 0.4202028810977936),
#  ('Tags & Tickets', 0.42016467452049255),
#  ('Crampons', 0.4201033413410187),
#  ('OS2', 0.4200890064239502),
#  ('People', 0.4199889898300171),
#  ('Revolutionary', 0.4199818968772888),
#  ('Camshafts', 0.41996192932128906),
#  ('Bathroom Storage & Organization', 0.4199441075325012),
#  ('Spiritual', 0.4198797941207886),
#  ('Buckles', 0.4198589622974396),
#  ('Democracy', 0.4198484420776367),
#  ('Lab Utensils', 0.4198419451713562),
#  ('Copenhagen', 0.41981828212738037),
#  ('Vietnam War', 0.41977858543395996),
#  ('Castors', 0.4197576940059662),
#  ('Outdoor Sports', 0.41970306634902954),
#  ('Shows', 0.4196609854698181),
#  ('Exterior Doors', 0.41961440443992615),
#  ('Paper Racks & Chart Stands', 0.4195811152458191),
#  ('Evangelism', 0.41950714588165283),
#  ('Solid Metal & Alloy Sheets', 0.41945725679397583),
#  ('Paleontology', 0.4194480776786804),
#  ('Literary', 0.419433057308197),
#  ('Skimming Nets', 0.4192827343940735),
#  ('Communications', 0.41923338174819946),
#  ('Communism & Socialism', 0.41915470361709595),
#  ('Dash Blower', 0.4190988540649414),
#  ('Occult', 0.4190756678581238),
#  ('Travel Writing', 0.419025719165802),
#  ('Hasidism', 0.41900625824928284),
#  ('Iran', 0.4188910126686096),
#  ('Auto Transmission Indicators', 0.41885724663734436),
#  ('Assemblies', 0.41873300075531006),
#  ('Firearms', 0.4187072217464447),
#  ('Broths', 0.4186868667602539),
#  ('Modernism', 0.4185871481895447),
#  ('Sewing Feet', 0.41858333349227905),
#  ('Tube Fittings', 0.41857704520225525),
#  ('Calcutta', 0.41857486963272095),
#  ('Hooves', 0.4185461401939392),
#  ('Banff', 0.41853734850883484),
#  ('Berry Spoons', 0.41850537061691284),
#  ('Folklore & Mythology', 0.41842979192733765),
#  ('State', 0.41842710971832275),
#  ('Lip Stains', 0.4183978736400604),
#  ('Ritual', 0.4183696508407593),
#  ('Water Sports', 0.4183611273765564),
#  ('Barbed Fittings', 0.418293833732605),
#  ('Colonial & Revolutionary', 0.41828933358192444),
#  ('Watering Cans', 0.4182663559913635),
#  ('Butt Terminals', 0.4182080328464508),
#  ('Thrillers', 0.4181470274925232),
#  ('Training Tools', 0.41813895106315613),
#  ('Certificate Covers', 0.4181221127510071),
#  ('Chemical Water Treaters', 0.41793394088745117),
#  ('Jesus', 0.4179190397262573),
#  ('Beading Hardware', 0.41788896918296814),
#  ('Growing Lamps', 0.41783052682876587),
#  ('Tire Chucks', 0.41780713200569153),
#  ('Foreign Language Study & Reference', 0.41777777671813965),
#  ('Filing Envelopes', 0.4177103638648987),
#  ('Clinical Psychology', 0.4175400137901306),
#  ('Earth-Based Religions', 0.41751158237457275),
#  ('Kamas', 0.4175105690956116),
#  ('Habitat D\x1acor', 0.41746336221694946),
#  ...]

# %%
string = 'Data is at the center of many challenges in system design today. Difficult issues need to be figured out, such as scalability, consistency, reliability, efficiency, and maintainability. In addition, we have an overwhelming variety of tools, including relational databases, NoSQL datastores, stream or batch processors, and message brokers. What are the right choices for your application? How do you make sense of all these buzzwords?'

# %%
test = ['2008', 'conducted', 'by', 'john', 'since', '1997', 'the', 'orchestra', 'is', 'defined', 'by', 'its', 'of', 'latin', 'american', 'music', 'here', 'the', 'orchestra', 'yet', 'again', 'the', 'listener', 'with', 'an', 'selection', 'of', 'and', 'latin', 'american', 'classics', 'including', 'w']

